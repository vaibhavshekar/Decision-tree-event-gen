# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Conv1D, GlobalMaxPooling1D, MultiHeadAttention, LayerNormalization, Attention
from tensorflow.keras.models import Model

# Data Preprocessing
def preprocess_data(df):
    event_type_mapping = df['event_type'].astype('category').cat.categories
    agent_id_mapping = df['agent_id'].astype('category').cat.categories
    context_mapping = df['context'].astype('category').cat.categories

    df['event_type'] = df['event_type'].astype('category').cat.codes
    df['agent_id'] = df['agent_id'].astype('category').cat.codes
    df['context'] = df['context'].astype('category').cat.codes

    return df, event_type_mapping, agent_id_mapping, context_mapping

# Load your dataset
df = pd.read_csv('1k_single_agent_minmax.csv')
df, event_type_mapping, agent_id_mapping, context_mapping = preprocess_data(df)

# Define constants
num_classes = df['event_type'].nunique()
num_agents = df['agent_id'].nunique()
num_contexts = df['context'].nunique()
sequence_length = 10  # Adjust based on your data
num_features = df.shape[1]  # Number of features

# Create sequences for training
def create_sequences(df, sequence_length):
    sequences = []
    for i in range(len(df) - sequence_length):
        seq = df.iloc[i:i+sequence_length].values
        sequences.append(seq)
    return np.array(sequences)

sequences = create_sequences(df, sequence_length)

# Splitting the data
train_size = int(0.7 * len(sequences))
val_size = int(0.15 * len(sequences))
train_sequences = sequences[:train_size]
val_sequences = sequences[train_size:train_size+val_size]
test_sequences = sequences[train_size+val_size:]

# Extract targets
def extract_targets(sequences):
    next_event = to_categorical(sequences[:, -1, 0], num_classes=num_classes)
    agent = to_categorical(sequences[:, -1, 1], num_classes=num_agents)
    context = to_categorical(sequences[:, -1, 2], num_classes=num_contexts)
    anomaly = np.random.randint(0, 2, size=(sequences.shape[0], 1))  # Placeholder for anomaly
    return next_event, agent, context, anomaly

train_targets = extract_targets(train_sequences)
val_targets = extract_targets(val_sequences)
test_targets = extract_targets(test_sequences)

# Define the model branches
def lstm_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = LSTM(128, return_sequences=True)(x)
    x = Attention()([x, x])
    x = GlobalMaxPooling1D()(x)
    return inputs, x

def transformer_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = LayerNormalization()(x + attn_output)
    x = GlobalMaxPooling1D()(x)  # Apply GlobalMaxPooling1D to convert 3D to 2D
    return inputs, x

def convnet_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = Conv1D(128, kernel_size=3, activation='relu')(x)
    x = GlobalMaxPooling1D()(x)
    return inputs, x

# Build the model
def build_model(sequence_length):
    input_shape = (sequence_length,)

    # Define the branches for each input
    lstm_event_inputs, lstm_event_output = lstm_branch(input_shape)
    lstm_agent_inputs, lstm_agent_output = lstm_branch(input_shape)
    lstm_context_inputs, lstm_context_output = lstm_branch(input_shape)
    
    transformer_event_inputs, transformer_event_output = transformer_branch(input_shape)
    transformer_agent_inputs, transformer_agent_output = transformer_branch(input_shape)
    transformer_context_inputs, transformer_context_output = transformer_branch(input_shape)
    
    convnet_event_inputs, convnet_event_output = convnet_branch(input_shape)
    convnet_agent_inputs, convnet_agent_output = convnet_branch(input_shape)
    convnet_context_inputs, convnet_context_output = convnet_branch(input_shape)
    
    # Concatenate outputs from all branches
    concatenated = Concatenate()([
        lstm_event_output, lstm_agent_output, lstm_context_output,
        transformer_event_output, transformer_agent_output, transformer_context_output,
        convnet_event_output, convnet_agent_output, convnet_context_output
    ])
    
    shared_dense = Dense(128, activation='relu')(concatenated)
    
    next_event_head = Dense(num_classes, activation='softmax', name='next_event')(shared_dense)
    agent_head = Dense(num_agents, activation='softmax', name='agent')(shared_dense)
    context_head = Dense(num_contexts, activation='softmax', name='context')(shared_dense)
    anomaly_head = Dense(1, activation='sigmoid', name='anomaly')(shared_dense)
    
    model = Model(inputs=[
        lstm_event_inputs, lstm_agent_inputs, lstm_context_inputs,
        transformer_event_inputs, transformer_agent_inputs, transformer_context_inputs,
        convnet_event_inputs, convnet_agent_inputs, convnet_context_inputs
    ], outputs=[next_event_head, agent_head, context_head, anomaly_head])
    
    return model

# Build the model
model = build_model(sequence_length)

# Define learnable uncertainty parameters
sigma_next_event = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_agent = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_context = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_anomaly = tf.Variable(1.0, dtype=tf.float32, trainable=True)

# Define custom loss functions with uncertainty weighting
def uncertainty_loss(y_true, y_pred, sigma):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)) / (2 * sigma ** 2) + tf.math.log(sigma)

# Define meta-learner model for learning rate adjustment
meta_input = Input(shape=(1,))
meta_output = Dense(1, activation='linear')(meta_input)
meta_model = Model(meta_input, meta_output)
meta_model.compile(optimizer='adam', loss='mse')

# Initial learning rate
initial_lr = 1e-3
model_optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)

# Compile the base model with the custom losses
model.compile(optimizer=model_optimizer,
              loss={'next_event': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_next_event),
                    'agent': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_agent),
                    'context': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_context),
                    'anomaly': lambda y_true, y_pred: tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred)) / (2 * sigma_anomaly ** 2) + tf.math.log(sigma_anomaly)},
              metrics={'next_event': 'accuracy', 
                       'agent': 'accuracy',
                       'context': 'accuracy',
                       'anomaly': 'accuracy'})

# Training the model with meta-learning
for epoch in range(50):
    print(f"Epoch {epoch+1}/50")
    
    # Train the base model
    history = model.fit(
        [train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
         train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
         train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2]],
        {'next_event': train_targets[0], 'agent': train_targets[1], 'context': train_targets[2], 'anomaly': train_targets[3]},
        validation_data=(
            [val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
             val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
             val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2]],
            {'next_event': val_targets[0], 'agent': val_targets[1], 'context': val_targets[2], 'anomaly': val_targets[3]}
        ),
        epochs=1, batch_size=64
    )
    
    # Get the validation loss
    val_loss = history.history['val_loss'][-1]
    
    # Meta-learning step: Update learning rate
    current_lr = model.optimizer.learning_rate.numpy()
    new_lr = meta_model.predict(np.array([[val_loss]]))
    new_lr = np.clip(new_lr, 1e-6, 1e-2)  # Clipping to prevent too large or small learning rates
    model.optimizer.learning_rate.assign(new_lr[0, 0])
    print(f"Updated learning rate: {new_lr[0][0]}")

history_df = pd.DataFrame(history.history)
history_df.to_csv('training_results/RNN_Combine_model_HirerchialAttn.csv', index=False)

# Evaluate the model
eval_results = model.evaluate(
    [test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2]],
    {'next_event': test_targets[0], 'agent': test_targets[1], 'context': test_targets[2], 'anomaly': test_targets[3]}
)

print(f"Test Results - Loss: {eval_results[0]}, Next Event Accuracy: {eval_results[1]}, Agent Accuracy: {eval_results[2]}, Context Accuracy: {eval_results[3]}, Anomaly Accuracy: {eval_results[4]}")
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 43s 282ms/step - agent_accuracy: 0.3694 - anomaly_accuracy: 0.5193 - context_accuracy: 0.0844 - loss: 2.6397 - next_event_accuracy: 0.7520 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6107 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - agent_accuracy: 0.4139 - anomaly_accuracy: 0.5032 - context_accuracy: 0.0862 - loss: 2.5839 - next_event_accuracy: 0.7983 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6100 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - agent_accuracy: 0.3884 - anomaly_accuracy: 0.5186 - context_accuracy: 0.0945 - loss: 2.5916 - next_event_accuracy: 0.7862 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6087 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - agent_accuracy: 0.4092 - anomaly_accuracy: 0.5186 - context_accuracy: 0.0896 - loss: 2.5893 - next_event_accuracy: 0.7853 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6074 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - agent_accuracy: 0.3840 - anomaly_accuracy: 0.4957 - context_accuracy: 0.0709 - loss: 2.5954 - next_event_accuracy: 0.7866 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6059 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - agent_accuracy: 0.3853 - anomaly_accuracy: 0.5277 - context_accuracy: 0.0884 - loss: 2.5853 - next_event_accuracy: 0.7879 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6046 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - agent_accuracy: 0.3953 - anomaly_accuracy: 0.5023 - context_accuracy: 0.0832 - loss: 2.5738 - next_event_accuracy: 0.8102 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6032 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - agent_accuracy: 0.4363 - anomaly_accuracy: 0.5005 - context_accuracy: 0.0935 - loss: 2.5676 - next_event_accuracy: 0.8171 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6019 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - agent_accuracy: 0.3745 - anomaly_accuracy: 0.5100 - context_accuracy: 0.0984 - loss: 2.5780 - next_event_accuracy: 0.7972 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.6006 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - agent_accuracy: 0.4036 - anomaly_accuracy: 0.5269 - context_accuracy: 0.0773 - loss: 2.5731 - next_event_accuracy: 0.7996 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5995 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - agent_accuracy: 0.4025 - anomaly_accuracy: 0.4930 - context_accuracy: 0.0940 - loss: 2.5696 - next_event_accuracy: 0.8123 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5982 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - agent_accuracy: 0.4212 - anomaly_accuracy: 0.4964 - context_accuracy: 0.0856 - loss: 2.5600 - next_event_accuracy: 0.8246 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5971 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - agent_accuracy: 0.3911 - anomaly_accuracy: 0.4895 - context_accuracy: 0.0815 - loss: 2.5729 - next_event_accuracy: 0.8109 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5960 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - agent_accuracy: 0.4010 - anomaly_accuracy: 0.5182 - context_accuracy: 0.0887 - loss: 2.5697 - next_event_accuracy: 0.8025 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5950 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - agent_accuracy: 0.4067 - anomaly_accuracy: 0.5073 - context_accuracy: 0.0907 - loss: 2.5642 - next_event_accuracy: 0.8096 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5939 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - agent_accuracy: 0.3928 - anomaly_accuracy: 0.4912 - context_accuracy: 0.0807 - loss: 2.5806 - next_event_accuracy: 0.7976 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5929 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - agent_accuracy: 0.3992 - anomaly_accuracy: 0.4883 - context_accuracy: 0.0870 - loss: 2.5634 - next_event_accuracy: 0.8168 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5920 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - agent_accuracy: 0.4137 - anomaly_accuracy: 0.5283 - context_accuracy: 0.0666 - loss: 2.5802 - next_event_accuracy: 0.7863 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5911 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - agent_accuracy: 0.3908 - anomaly_accuracy: 0.5202 - context_accuracy: 0.0817 - loss: 2.5614 - next_event_accuracy: 0.8125 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5902 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - agent_accuracy: 0.4111 - anomaly_accuracy: 0.5325 - context_accuracy: 0.0916 - loss: 2.5614 - next_event_accuracy: 0.8058 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5894 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - agent_accuracy: 0.3979 - anomaly_accuracy: 0.5153 - context_accuracy: 0.0994 - loss: 2.5716 - next_event_accuracy: 0.7946 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5885 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - agent_accuracy: 0.4072 - anomaly_accuracy: 0.5120 - context_accuracy: 0.0882 - loss: 2.5738 - next_event_accuracy: 0.7954 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5877 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - agent_accuracy: 0.4073 - anomaly_accuracy: 0.5074 - context_accuracy: 0.0877 - loss: 2.5697 - next_event_accuracy: 0.7990 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5870 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - agent_accuracy: 0.3701 - anomaly_accuracy: 0.4991 - context_accuracy: 0.0931 - loss: 2.5686 - next_event_accuracy: 0.8038 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5863 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - agent_accuracy: 0.3989 - anomaly_accuracy: 0.5127 - context_accuracy: 0.0809 - loss: 2.5737 - next_event_accuracy: 0.7932 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5856 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - agent_accuracy: 0.3821 - anomaly_accuracy: 0.5111 - context_accuracy: 0.0778 - loss: 2.5840 - next_event_accuracy: 0.7830 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5849 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - agent_accuracy: 0.3865 - anomaly_accuracy: 0.4945 - context_accuracy: 0.0961 - loss: 2.5537 - next_event_accuracy: 0.8208 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5843 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - agent_accuracy: 0.3995 - anomaly_accuracy: 0.5077 - context_accuracy: 0.0811 - loss: 2.5695 - next_event_accuracy: 0.7982 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5836 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - agent_accuracy: 0.3873 - anomaly_accuracy: 0.4967 - context_accuracy: 0.0998 - loss: 2.5637 - next_event_accuracy: 0.8057 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5830 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - agent_accuracy: 0.4005 - anomaly_accuracy: 0.4737 - context_accuracy: 0.0852 - loss: 2.5661 - next_event_accuracy: 0.8088 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5824 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - agent_accuracy: 0.4071 - anomaly_accuracy: 0.4894 - context_accuracy: 0.0934 - loss: 2.5781 - next_event_accuracy: 0.7882 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5819 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - agent_accuracy: 0.4068 - anomaly_accuracy: 0.4854 - context_accuracy: 0.1031 - loss: 2.5500 - next_event_accuracy: 0.8236 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5814 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - agent_accuracy: 0.4053 - anomaly_accuracy: 0.5073 - context_accuracy: 0.0881 - loss: 2.5743 - next_event_accuracy: 0.7923 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5809 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 310ms/step - agent_accuracy: 0.3806 - anomaly_accuracy: 0.5158 - context_accuracy: 0.0983 - loss: 2.5645 - next_event_accuracy: 0.8021 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5804 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - agent_accuracy: 0.4145 - anomaly_accuracy: 0.5129 - context_accuracy: 0.0975 - loss: 2.5521 - next_event_accuracy: 0.8151 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5799 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - agent_accuracy: 0.4045 - anomaly_accuracy: 0.5127 - context_accuracy: 0.0894 - loss: 2.5605 - next_event_accuracy: 0.8052 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5795 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - agent_accuracy: 0.3866 - anomaly_accuracy: 0.5219 - context_accuracy: 0.0793 - loss: 2.5657 - next_event_accuracy: 0.8005 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5790 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - agent_accuracy: 0.3971 - anomaly_accuracy: 0.4903 - context_accuracy: 0.0752 - loss: 2.5825 - next_event_accuracy: 0.7863 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4257 - val_context_accuracy: 0.0946 - val_loss: 2.5786 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - agent_accuracy: 0.3851 - anomaly_accuracy: 0.5306 - context_accuracy: 0.0729 - loss: 2.5646 - next_event_accuracy: 0.8020 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4324 - val_context_accuracy: 0.0946 - val_loss: 2.5782 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - agent_accuracy: 0.3851 - anomaly_accuracy: 0.5139 - context_accuracy: 0.0992 - loss: 2.5601 - next_event_accuracy: 0.8079 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4189 - val_context_accuracy: 0.0946 - val_loss: 2.5778 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - agent_accuracy: 0.4320 - anomaly_accuracy: 0.5008 - context_accuracy: 0.0937 - loss: 2.5655 - next_event_accuracy: 0.8027 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5774 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - agent_accuracy: 0.4006 - anomaly_accuracy: 0.5241 - context_accuracy: 0.1002 - loss: 2.5700 - next_event_accuracy: 0.7950 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5770 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - agent_accuracy: 0.4240 - anomaly_accuracy: 0.5263 - context_accuracy: 0.0914 - loss: 2.5480 - next_event_accuracy: 0.8228 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5767 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - agent_accuracy: 0.3693 - anomaly_accuracy: 0.5466 - context_accuracy: 0.0895 - loss: 2.5735 - next_event_accuracy: 0.7853 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5765 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - agent_accuracy: 0.3969 - anomaly_accuracy: 0.5416 - context_accuracy: 0.1054 - loss: 2.5731 - next_event_accuracy: 0.7854 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5761 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - agent_accuracy: 0.4099 - anomaly_accuracy: 0.5002 - context_accuracy: 0.0782 - loss: 2.5740 - next_event_accuracy: 0.7925 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5758 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - agent_accuracy: 0.3961 - anomaly_accuracy: 0.5205 - context_accuracy: 0.0815 - loss: 2.5768 - next_event_accuracy: 0.7840 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5755 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - agent_accuracy: 0.3833 - anomaly_accuracy: 0.5203 - context_accuracy: 0.0976 - loss: 2.5713 - next_event_accuracy: 0.7920 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5753 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - agent_accuracy: 0.4122 - anomaly_accuracy: 0.5384 - context_accuracy: 0.0933 - loss: 2.5631 - next_event_accuracy: 0.8001 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5750 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - agent_accuracy: 0.4050 - anomaly_accuracy: 0.5284 - context_accuracy: 0.0996 - loss: 2.5514 - next_event_accuracy: 0.8146 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.0946 - val_loss: 2.5747 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Updated learning rate: 9.999999974752427e-07
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - agent_accuracy: 0.4020 - anomaly_accuracy: 0.5467 - context_accuracy: 0.0893 - loss: 2.5639 - next_event_accuracy: 0.8018
# Test Results - Loss: 2.567180633544922, Next Event Accuracy: 0.4026845693588257, Agent Accuracy: 0.5436241626739502, Context Accuracy: 0.08053690940141678, Anomaly Accuracy: 0.7986577153205872

# %%
num_samples = 10
sample_sequences = test_sequences[:num_samples]

# Predict the next values
predictions = model.predict(
    [sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2]]
)

# Extract predictions
next_event_predictions = np.argmax(predictions[0], axis=-1)
agent_predictions = np.argmax(predictions[1], axis=-1)
context_predictions = np.argmax(predictions[2], axis=-1)
anomaly_predictions = (predictions[3] > 0.5).astype(int)

# Decode predictions
def decode_predictions(predictions, id_to_label):
    return [id_to_label[idx] for idx in predictions]

decoded_next_event_predictions = decode_predictions(next_event_predictions, event_type_mapping)
decoded_agent_predictions = decode_predictions(agent_predictions, agent_id_mapping)
decoded_context_predictions = decode_predictions(context_predictions, context_mapping)

# Decode input sequences
def decode_sequences(sequences, event_mapping, agent_mapping, context_mapping):
    decoded_sequences = []
    for seq in sequences:
        decoded_seq = []
        for step in seq:
            decoded_step = [
                event_mapping[step[0]],
                agent_mapping[step[1]],
                context_mapping[step[2]]
            ]
            decoded_seq.append(decoded_step)
        decoded_sequences.append(decoded_seq)
    return np.array(decoded_sequences)

decoded_sample_sequences = decode_sequences(sample_sequences, event_type_mapping, agent_id_mapping, context_mapping)

# Print decoded input sequences and predictions
for i in range(num_samples):
    print(f"Input sequence (event_id, agent_id, context):\n{decoded_sample_sequences[i]}")
    print(f"Predicted next event_id: {decoded_next_event_predictions[i]}")
    print(f"Predicted next agent_id: {decoded_agent_predictions[i]}")
    print(f"Predicted next context: {decoded_context_predictions[i]}")
    print(f"Predicted anomaly: {anomaly_predictions[i]}")
    print("-" * 30)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '2,2']
#  ['MOVE' 'opponent_move' '1,2']
#  ['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,2']
#  ['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 1,1
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 1,1
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 1,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 1,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 1,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']
#  ['MOVE' 'opponent_move' '1,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 1,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '1,2']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,2
# Predicted anomaly: [0]
# ------------------------------
