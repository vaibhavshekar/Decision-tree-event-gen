# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Conv1D, GlobalMaxPooling1D, MultiHeadAttention, LayerNormalization, Attention
from tensorflow.keras.models import Model

# Data Preprocessing
def preprocess_data(df):
    event_type_mapping = df['event_type'].astype('category').cat.categories
    agent_id_mapping = df['agent_id'].astype('category').cat.categories
    context_mapping = df['context'].astype('category').cat.categories

    df['event_type'] = df['event_type'].astype('category').cat.codes
    df['agent_id'] = df['agent_id'].astype('category').cat.codes
    df['context'] = df['context'].astype('category').cat.codes

    return df, event_type_mapping, agent_id_mapping, context_mapping

# Load your dataset
df = pd.read_csv('1k_single_agent_minmax.csv')
df, event_type_mapping, agent_id_mapping, context_mapping = preprocess_data(df)

# Define constants
num_classes = df['event_type'].nunique()
num_agents = df['agent_id'].nunique()
num_contexts = df['context'].nunique()
sequence_length = 10  # Adjust based on your data
num_features = df.shape[1]  # Number of features

# Create sequences for training
def create_sequences(df, sequence_length):
    sequences = []
    for i in range(len(df) - sequence_length):
        seq = df.iloc[i:i+sequence_length].values
        sequences.append(seq)
    return np.array(sequences)

sequences = create_sequences(df, sequence_length)

# Splitting the data
train_size = int(0.7 * len(sequences))
val_size = int(0.15 * len(sequences))
train_sequences = sequences[:train_size]
val_sequences = sequences[train_size:train_size+val_size]
test_sequences = sequences[train_size+val_size:]

# Extract targets
def extract_targets(sequences):
    next_event = to_categorical(sequences[:, -1, 0], num_classes=num_classes)
    agent = to_categorical(sequences[:, -1, 1], num_classes=num_agents)
    context = to_categorical(sequences[:, -1, 2], num_classes=num_contexts)
    anomaly = np.random.randint(0, 2, size=(sequences.shape[0], 1))  # Placeholder for anomaly
    return next_event, agent, context, anomaly

train_targets = extract_targets(train_sequences)
val_targets = extract_targets(val_sequences)
test_targets = extract_targets(test_sequences)

# Define the model branches
def lstm_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = LSTM(128, return_sequences=True)(x)
    x = Attention()([x, x])
    x = GlobalMaxPooling1D()(x)
    return inputs, x

def transformer_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = LayerNormalization()(x + attn_output)
    x = GlobalMaxPooling1D()(x)  # Apply GlobalMaxPooling1D to convert 3D to 2D
    return inputs, x

def convnet_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = Conv1D(128, kernel_size=3, activation='relu')(x)
    x = GlobalMaxPooling1D()(x)
    return inputs, x

# Build the model
def build_model(sequence_length):
    input_shape = (sequence_length,)

    # Define the branches for each input
    lstm_event_inputs, lstm_event_output = lstm_branch(input_shape)
    lstm_agent_inputs, lstm_agent_output = lstm_branch(input_shape)
    lstm_context_inputs, lstm_context_output = lstm_branch(input_shape)
    
    transformer_event_inputs, transformer_event_output = transformer_branch(input_shape)
    transformer_agent_inputs, transformer_agent_output = transformer_branch(input_shape)
    transformer_context_inputs, transformer_context_output = transformer_branch(input_shape)
    
    convnet_event_inputs, convnet_event_output = convnet_branch(input_shape)
    convnet_agent_inputs, convnet_agent_output = convnet_branch(input_shape)
    convnet_context_inputs, convnet_context_output = convnet_branch(input_shape)
    
    # Concatenate outputs from all branches
    concatenated = Concatenate()([
        lstm_event_output, lstm_agent_output, lstm_context_output,
        transformer_event_output, transformer_agent_output, transformer_context_output,
        convnet_event_output, convnet_agent_output, convnet_context_output
    ])
    
    shared_dense = Dense(128, activation='relu')(concatenated)
    
    next_event_head = Dense(num_classes, activation='softmax', name='next_event')(shared_dense)
    agent_head = Dense(num_agents, activation='softmax', name='agent')(shared_dense)
    context_head = Dense(num_contexts, activation='softmax', name='context')(shared_dense)
    anomaly_head = Dense(1, activation='sigmoid', name='anomaly')(shared_dense)
    
    model = Model(inputs=[
        lstm_event_inputs, lstm_agent_inputs, lstm_context_inputs,
        transformer_event_inputs, transformer_agent_inputs, transformer_context_inputs,
        convnet_event_inputs, convnet_agent_inputs, convnet_context_inputs
    ], outputs=[next_event_head, agent_head, context_head, anomaly_head])
    
    return model

# Build the model
model = build_model(sequence_length)

# Define learnable uncertainty parameters
sigma_next_event = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_agent = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_context = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_anomaly = tf.Variable(1.0, dtype=tf.float32, trainable=True)

# Define custom loss functions with uncertainty weighting
def uncertainty_loss(y_true, y_pred, sigma):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)) / (2 * sigma ** 2) + tf.math.log(sigma)

# Define meta-learner model for learning rate adjustment
meta_input = Input(shape=(1,))
meta_output = Dense(1, activation='linear')(meta_input)
meta_model = Model(meta_input, meta_output)
meta_model.compile(optimizer='adam', loss='mse')

# Initial learning rate
initial_lr = 1e-3
model_optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)

# Compile the base model with the custom losses
model.compile(optimizer=model_optimizer,
              loss={'next_event': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_next_event),
                    'agent': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_agent),
                    'context': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_context),
                    'anomaly': lambda y_true, y_pred: tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred)) / (2 * sigma_anomaly ** 2) + tf.math.log(sigma_anomaly)},
              metrics={'next_event': 'accuracy', 
                       'agent': 'accuracy',
                       'context': 'accuracy',
                       'anomaly': 'accuracy'})

# Training the model with meta-learning
for epoch in range(50):
    print(f"Epoch {epoch+1}/50")
    
    # Train the base model
    history = model.fit(
        [train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
         train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
         train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2]],
        {'next_event': train_targets[0], 'agent': train_targets[1], 'context': train_targets[2], 'anomaly': train_targets[3]},
        validation_data=(
            [val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
             val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
             val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2]],
            {'next_event': val_targets[0], 'agent': val_targets[1], 'context': val_targets[2], 'anomaly': val_targets[3]}
        ),
        epochs=1, batch_size=64
    )
    
    # Get the validation loss
    val_loss = history.history['val_loss'][-1]
    
    # Meta-learning step: Update learning rate
    current_lr = model.optimizer.learning_rate.numpy()
    new_lr = meta_model.predict(np.array([[val_loss]]))
    new_lr = np.clip(new_lr, 1e-6, 1e-2)  # Clipping to prevent too large or small learning rates
    model.optimizer.learning_rate.assign(new_lr[0, 0])
    print(f"Updated learning rate: {new_lr[0][0]}")

# Evaluate the model
eval_results = model.evaluate(
    [test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2]],
    {'next_event': test_targets[0], 'agent': test_targets[1], 'context': test_targets[2], 'anomaly': test_targets[3]}
)

print(f"Test Results - Loss: {eval_results[0]}, Next Event Accuracy: {eval_results[1]}, Agent Accuracy: {eval_results[2]}, Context Accuracy: {eval_results[3]}, Anomaly Accuracy: {eval_results[4]}")
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 46s 528ms/step - agent_accuracy: 0.3590 - anomaly_accuracy: 0.4888 - context_accuracy: 0.0748 - loss: 2.6649 - next_event_accuracy: 0.5969 - val_agent_accuracy: 0.5493 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1056 - val_loss: 2.5340 - val_next_event_accuracy: 0.8028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - agent_accuracy: 0.4913 - anomaly_accuracy: 0.4759 - context_accuracy: 0.1458 - loss: 2.5898 - next_event_accuracy: 0.7889 - val_agent_accuracy: 0.4366 - val_anomaly_accuracy: 0.4930 - val_context_accuracy: 0.1408 - val_loss: 2.5675 - val_next_event_accuracy: 0.8028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - agent_accuracy: 0.4278 - anomaly_accuracy: 0.5701 - context_accuracy: 0.1054 - loss: 2.5693 - next_event_accuracy: 0.8005 - val_agent_accuracy: 0.4366 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1831 - val_loss: 2.5350 - val_next_event_accuracy: 0.8028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - agent_accuracy: 0.4717 - anomaly_accuracy: 0.5426 - context_accuracy: 0.1841 - loss: 2.5213 - next_event_accuracy: 0.7921 - val_agent_accuracy: 0.5493 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1761 - val_loss: 2.5212 - val_next_event_accuracy: 0.8028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - agent_accuracy: 0.5521 - anomaly_accuracy: 0.5146 - context_accuracy: 0.1867 - loss: 2.4899 - next_event_accuracy: 0.7904 - val_agent_accuracy: 0.5070 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1831 - val_loss: 2.4760 - val_next_event_accuracy: 0.8169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 505ms/step - agent_accuracy: 0.5496 - anomaly_accuracy: 0.5438 - context_accuracy: 0.1542 - loss: 2.4906 - next_event_accuracy: 0.7785 - val_agent_accuracy: 0.5352 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.1690 - val_loss: 2.4592 - val_next_event_accuracy: 0.8169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - agent_accuracy: 0.5464 - anomaly_accuracy: 0.5018 - context_accuracy: 0.1633 - loss: 2.4619 - next_event_accuracy: 0.8231 - val_agent_accuracy: 0.5775 - val_anomaly_accuracy: 0.5282 - val_context_accuracy: 0.1690 - val_loss: 2.4347 - val_next_event_accuracy: 0.8592
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - agent_accuracy: 0.5852 - anomaly_accuracy: 0.5363 - context_accuracy: 0.1826 - loss: 2.4461 - next_event_accuracy: 0.8132 - val_agent_accuracy: 0.5775 - val_anomaly_accuracy: 0.5211 - val_context_accuracy: 0.1690 - val_loss: 2.3967 - val_next_event_accuracy: 0.8803
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - agent_accuracy: 0.5921 - anomaly_accuracy: 0.4988 - context_accuracy: 0.2024 - loss: 2.3890 - next_event_accuracy: 0.8726 - val_agent_accuracy: 0.5775 - val_anomaly_accuracy: 0.5211 - val_context_accuracy: 0.1690 - val_loss: 2.3778 - val_next_event_accuracy: 0.8873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - agent_accuracy: 0.5640 - anomaly_accuracy: 0.5358 - context_accuracy: 0.1775 - loss: 2.3700 - next_event_accuracy: 0.8969 - val_agent_accuracy: 0.7324 - val_anomaly_accuracy: 0.4648 - val_context_accuracy: 0.1620 - val_loss: 2.3237 - val_next_event_accuracy: 0.8873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 390ms/step - agent_accuracy: 0.7895 - anomaly_accuracy: 0.5426 - context_accuracy: 0.1819 - loss: 2.2874 - next_event_accuracy: 0.9160 - val_agent_accuracy: 0.8028 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1620 - val_loss: 2.3770 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - agent_accuracy: 0.6339 - anomaly_accuracy: 0.4974 - context_accuracy: 0.1850 - loss: 2.3619 - next_event_accuracy: 0.9468 - val_agent_accuracy: 0.6056 - val_anomaly_accuracy: 0.5211 - val_context_accuracy: 0.1761 - val_loss: 2.4144 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 377ms/step - agent_accuracy: 0.5991 - anomaly_accuracy: 0.5129 - context_accuracy: 0.1665 - loss: 2.4211 - next_event_accuracy: 0.9266 - val_agent_accuracy: 0.7183 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.1549 - val_loss: 2.3200 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - agent_accuracy: 0.7925 - anomaly_accuracy: 0.5099 - context_accuracy: 0.1766 - loss: 2.3073 - next_event_accuracy: 0.9270 - val_agent_accuracy: 0.7746 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1620 - val_loss: 2.2941 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - agent_accuracy: 0.8221 - anomaly_accuracy: 0.5116 - context_accuracy: 0.1673 - loss: 2.2655 - next_event_accuracy: 0.9355 - val_agent_accuracy: 0.7746 - val_anomaly_accuracy: 0.5352 - val_context_accuracy: 0.1620 - val_loss: 2.2848 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - agent_accuracy: 0.8411 - anomaly_accuracy: 0.5276 - context_accuracy: 0.1812 - loss: 2.2488 - next_event_accuracy: 0.9315 - val_agent_accuracy: 0.7746 - val_anomaly_accuracy: 0.5352 - val_context_accuracy: 0.1479 - val_loss: 2.2792 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.8261 - anomaly_accuracy: 0.5024 - context_accuracy: 0.2048 - loss: 2.2609 - next_event_accuracy: 0.9182 - val_agent_accuracy: 0.7746 - val_anomaly_accuracy: 0.4648 - val_context_accuracy: 0.1338 - val_loss: 2.2843 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - agent_accuracy: 0.8213 - anomaly_accuracy: 0.4986 - context_accuracy: 0.1777 - loss: 2.2576 - next_event_accuracy: 0.9358 - val_agent_accuracy: 0.7746 - val_anomaly_accuracy: 0.6056 - val_context_accuracy: 0.1620 - val_loss: 2.2774 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - agent_accuracy: 0.8366 - anomaly_accuracy: 0.5469 - context_accuracy: 0.1824 - loss: 2.2446 - next_event_accuracy: 0.9398 - val_agent_accuracy: 0.7887 - val_anomaly_accuracy: 0.5915 - val_context_accuracy: 0.1549 - val_loss: 2.2581 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - agent_accuracy: 0.8368 - anomaly_accuracy: 0.5460 - context_accuracy: 0.2245 - loss: 2.2255 - next_event_accuracy: 0.9315 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5211 - val_context_accuracy: 0.1972 - val_loss: 2.2324 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - agent_accuracy: 0.8555 - anomaly_accuracy: 0.5538 - context_accuracy: 0.2768 - loss: 2.2146 - next_event_accuracy: 0.9174 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.2042 - val_loss: 2.2362 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - agent_accuracy: 0.8784 - anomaly_accuracy: 0.5134 - context_accuracy: 0.2376 - loss: 2.2162 - next_event_accuracy: 0.9321 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1620 - val_loss: 2.2271 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - agent_accuracy: 0.8544 - anomaly_accuracy: 0.4967 - context_accuracy: 0.2707 - loss: 2.2178 - next_event_accuracy: 0.9166 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5493 - val_context_accuracy: 0.1761 - val_loss: 2.2364 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - agent_accuracy: 0.8657 - anomaly_accuracy: 0.5220 - context_accuracy: 0.2356 - loss: 2.2160 - next_event_accuracy: 0.9291 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.6056 - val_context_accuracy: 0.1690 - val_loss: 2.2296 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.8782 - anomaly_accuracy: 0.5315 - context_accuracy: 0.2524 - loss: 2.1976 - next_event_accuracy: 0.9365 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5704 - val_context_accuracy: 0.1761 - val_loss: 2.2318 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - agent_accuracy: 0.8758 - anomaly_accuracy: 0.5387 - context_accuracy: 0.2244 - loss: 2.2138 - next_event_accuracy: 0.9333 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5915 - val_context_accuracy: 0.1690 - val_loss: 2.2293 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.8980 - anomaly_accuracy: 0.5332 - context_accuracy: 0.2398 - loss: 2.1953 - next_event_accuracy: 0.9449 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5986 - val_context_accuracy: 0.1620 - val_loss: 2.2299 - val_next_event_accuracy: 0.9437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.8606 - anomaly_accuracy: 0.5418 - context_accuracy: 0.2832 - loss: 2.1942 - next_event_accuracy: 0.9481 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5423 - val_context_accuracy: 0.1761 - val_loss: 2.2168 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - agent_accuracy: 0.8726 - anomaly_accuracy: 0.5513 - context_accuracy: 0.2506 - loss: 2.1839 - next_event_accuracy: 0.9660 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5282 - val_context_accuracy: 0.1972 - val_loss: 2.2153 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - agent_accuracy: 0.8877 - anomaly_accuracy: 0.5693 - context_accuracy: 0.2603 - loss: 2.1715 - next_event_accuracy: 0.9698 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5634 - val_context_accuracy: 0.1761 - val_loss: 2.2172 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - agent_accuracy: 0.8997 - anomaly_accuracy: 0.5681 - context_accuracy: 0.2726 - loss: 2.1618 - next_event_accuracy: 0.9757 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5704 - val_context_accuracy: 0.1831 - val_loss: 2.2223 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.8749 - anomaly_accuracy: 0.5415 - context_accuracy: 0.2545 - loss: 2.1912 - next_event_accuracy: 0.9621 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1761 - val_loss: 2.2172 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - agent_accuracy: 0.9062 - anomaly_accuracy: 0.5277 - context_accuracy: 0.2669 - loss: 2.1599 - next_event_accuracy: 0.9739 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5775 - val_context_accuracy: 0.1901 - val_loss: 2.2227 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - agent_accuracy: 0.8627 - anomaly_accuracy: 0.5519 - context_accuracy: 0.2741 - loss: 2.1875 - next_event_accuracy: 0.9623 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5563 - val_context_accuracy: 0.1831 - val_loss: 2.2160 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - agent_accuracy: 0.8933 - anomaly_accuracy: 0.5374 - context_accuracy: 0.2518 - loss: 2.1719 - next_event_accuracy: 0.9739 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5634 - val_context_accuracy: 0.1831 - val_loss: 2.2168 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - agent_accuracy: 0.8669 - anomaly_accuracy: 0.5177 - context_accuracy: 0.2677 - loss: 2.1790 - next_event_accuracy: 0.9596 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5704 - val_context_accuracy: 0.1901 - val_loss: 2.2219 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - agent_accuracy: 0.8868 - anomaly_accuracy: 0.5482 - context_accuracy: 0.2483 - loss: 2.1748 - next_event_accuracy: 0.9709 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5634 - val_context_accuracy: 0.1901 - val_loss: 2.2152 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - agent_accuracy: 0.8926 - anomaly_accuracy: 0.5760 - context_accuracy: 0.2472 - loss: 2.1683 - next_event_accuracy: 0.9663 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5211 - val_context_accuracy: 0.1761 - val_loss: 2.2296 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - agent_accuracy: 0.8865 - anomaly_accuracy: 0.5460 - context_accuracy: 0.2653 - loss: 2.1723 - next_event_accuracy: 0.9677 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5775 - val_context_accuracy: 0.1901 - val_loss: 2.2190 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - agent_accuracy: 0.8818 - anomaly_accuracy: 0.5343 - context_accuracy: 0.2802 - loss: 2.1727 - next_event_accuracy: 0.9646 - val_agent_accuracy: 0.8592 - val_anomaly_accuracy: 0.5423 - val_context_accuracy: 0.2042 - val_loss: 2.2160 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - agent_accuracy: 0.8829 - anomaly_accuracy: 0.5543 - context_accuracy: 0.2244 - loss: 2.1900 - next_event_accuracy: 0.9643 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5282 - val_context_accuracy: 0.2042 - val_loss: 2.2013 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.9155 - anomaly_accuracy: 0.4946 - context_accuracy: 0.2574 - loss: 2.1727 - next_event_accuracy: 0.9585 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5634 - val_context_accuracy: 0.1761 - val_loss: 2.2022 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.9153 - anomaly_accuracy: 0.5717 - context_accuracy: 0.2869 - loss: 2.1538 - next_event_accuracy: 0.9629 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5915 - val_context_accuracy: 0.1831 - val_loss: 2.2025 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - agent_accuracy: 0.9178 - anomaly_accuracy: 0.5514 - context_accuracy: 0.2752 - loss: 2.1574 - next_event_accuracy: 0.9672 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.6056 - val_context_accuracy: 0.1901 - val_loss: 2.2060 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - agent_accuracy: 0.9226 - anomaly_accuracy: 0.5801 - context_accuracy: 0.3095 - loss: 2.1352 - next_event_accuracy: 0.9639 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5915 - val_context_accuracy: 0.1831 - val_loss: 2.2020 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - agent_accuracy: 0.9187 - anomaly_accuracy: 0.5417 - context_accuracy: 0.2958 - loss: 2.1480 - next_event_accuracy: 0.9630 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.6056 - val_context_accuracy: 0.1972 - val_loss: 2.2007 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - agent_accuracy: 0.9181 - anomaly_accuracy: 0.5580 - context_accuracy: 0.2636 - loss: 2.1533 - next_event_accuracy: 0.9649 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5423 - val_context_accuracy: 0.1901 - val_loss: 2.2153 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - agent_accuracy: 0.9326 - anomaly_accuracy: 0.5073 - context_accuracy: 0.2577 - loss: 2.1613 - next_event_accuracy: 0.9772 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5915 - val_context_accuracy: 0.1761 - val_loss: 2.2132 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - agent_accuracy: 0.9132 - anomaly_accuracy: 0.5586 - context_accuracy: 0.2648 - loss: 2.1551 - next_event_accuracy: 0.9721 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5563 - val_context_accuracy: 0.1901 - val_loss: 2.2114 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Updated learning rate: 0.009999999776482582
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - agent_accuracy: 0.8964 - anomaly_accuracy: 0.5729 - context_accuracy: 0.2503 - loss: 2.1748 - next_event_accuracy: 0.9545 - val_agent_accuracy: 0.8873 - val_anomaly_accuracy: 0.5634 - val_context_accuracy: 0.1972 - val_loss: 2.2029 - val_next_event_accuracy: 0.9718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Updated learning rate: 0.009999999776482582
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - agent_accuracy: 0.8229 - anomaly_accuracy: 0.6076 - context_accuracy: 0.1934 - loss: 2.2538 - next_event_accuracy: 0.9050
# Test Results - Loss: 2.1932857036590576, Next Event Accuracy: 0.8881118893623352, Agent Accuracy: 0.6013985872268677, Context Accuracy: 0.21678321063518524, Anomaly Accuracy: 0.9440559148788452

# %%
num_samples = 10
sample_sequences = test_sequences[:num_samples]

# Predict the next values
predictions = model.predict(
    [sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2]]
)

# Extract predictions
next_event_predictions = np.argmax(predictions[0], axis=-1)
agent_predictions = np.argmax(predictions[1], axis=-1)
context_predictions = np.argmax(predictions[2], axis=-1)
anomaly_predictions = (predictions[3] > 0.5).astype(int)

# Decode predictions
def decode_predictions(predictions, id_to_label):
    return [id_to_label[idx] for idx in predictions]

decoded_next_event_predictions = decode_predictions(next_event_predictions, event_type_mapping)
decoded_agent_predictions = decode_predictions(agent_predictions, agent_id_mapping)
decoded_context_predictions = decode_predictions(context_predictions, context_mapping)

# Decode input sequences
def decode_sequences(sequences, event_mapping, agent_mapping, context_mapping):
    decoded_sequences = []
    for seq in sequences:
        decoded_seq = []
        for step in seq:
            decoded_step = [
                event_mapping[step[0]],
                agent_mapping[step[1]],
                context_mapping[step[2]]
            ]
            decoded_seq.append(decoded_step)
        decoded_sequences.append(decoded_seq)
    return np.array(decoded_sequences)

decoded_sample_sequences = decode_sequences(sample_sequences, event_type_mapping, agent_id_mapping, context_mapping)

# Print decoded input sequences and predictions
for i in range(num_samples):
    print(f"Input sequence (event_id, agent_id, context):\n{decoded_sample_sequences[i]}")
    print(f"Predicted next event_id: {decoded_next_event_predictions[i]}")
    print(f"Predicted next agent_id: {decoded_agent_predictions[i]}")
    print(f"Predicted next context: {decoded_context_predictions[i]}")
    print(f"Predicted anomaly: {anomaly_predictions[i]}")
    print("-" * 30)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step
# Input sequence (event_id, agent_id, context):
# [['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,0']
#  ['MOVE' 'O' '0,2']
#  ['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']]
# Predicted next event_id: GAME_END
# Predicted next agent_id: system
# Predicted next context: O
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '1,0']
#  ['MOVE' 'O' '0,2']
#  ['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']]
# Predicted next event_id: GAME_START
# Predicted next agent_id: system
# Predicted next context: New Game
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '0,2']
#  ['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 1,2
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: O
# Predicted next context: 2,2
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 0,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: O
# Predicted next context: 1,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 0,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: O
# Predicted next context: 0,2
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['MOVE' 'X' '0,2']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['MOVE' 'X' '0,2']
#  ['GAME_END' 'system' 'X']]
# Predicted next event_id: GAME_END
# Predicted next agent_id: system
# Predicted next context: X
# Predicted anomaly: [1]
# ------------------------------
