# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Conv1D, GlobalMaxPooling1D, MultiHeadAttention, LayerNormalization
from tensorflow.keras.models import Model

# Data Preprocessing
def preprocess_data(df):
    event_type_mapping = df['event_type'].astype('category').cat.categories
    agent_id_mapping = df['agent_id'].astype('category').cat.categories
    context_mapping = df['context'].astype('category').cat.categories

    df['event_type'] = df['event_type'].astype('category').cat.codes
    df['agent_id'] = df['agent_id'].astype('category').cat.codes
    df['context'] = df['context'].astype('category').cat.codes

    return df, event_type_mapping, agent_id_mapping, context_mapping

# Load your dataset
df = pd.read_csv('1k_single_agent_minmax.csv')
df, event_type_mapping, agent_id_mapping, context_mapping = preprocess_data(df)

# Define constants
num_classes = df['event_type'].nunique()
num_agents = df['agent_id'].nunique()
num_contexts = df['context'].nunique()
sequence_length = 10  # Adjust based on your data
num_features = df.shape[1]  # Number of features

# Create sequences for training
def create_sequences(df, sequence_length):
    sequences = []
    for i in range(len(df) - sequence_length):
        seq = df.iloc[i:i+sequence_length].values
        sequences.append(seq)
    return np.array(sequences)

sequences = create_sequences(df, sequence_length)

# Splitting the data
train_size = int(0.7 * len(sequences))
val_size = int(0.15 * len(sequences))
train_sequences = sequences[:train_size]
val_sequences = sequences[train_size:train_size+val_size]
test_sequences = sequences[train_size+val_size:]

# Extract targets
def extract_targets(sequences):
    next_event = to_categorical(sequences[:, -1, 0], num_classes=num_classes)
    agent = to_categorical(sequences[:, -1, 1], num_classes=num_agents)
    context = to_categorical(sequences[:, -1, 2], num_classes=num_contexts)
    anomaly = np.random.randint(0, 2, size=(sequences.shape[0], 1))  # Placeholder for anomaly
    return next_event, agent, context, anomaly

train_targets = extract_targets(train_sequences)
val_targets = extract_targets(val_sequences)
test_targets = extract_targets(test_sequences)

# Define the model branches
def lstm_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = LSTM(128, return_sequences=False)(x)
    return inputs, x

def transformer_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = LayerNormalization()(x + attn_output)
    x = GlobalMaxPooling1D()(x)  # Apply GlobalMaxPooling1D to convert 3D to 2D
    return inputs, x

def convnet_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = Conv1D(128, kernel_size=3, activation='relu')(x)
    x = GlobalMaxPooling1D()(x)
    return inputs, x

# Build the model
def build_model(sequence_length):
    input_shape = (sequence_length,)

    # Define the branches for each input
    lstm_event_inputs, lstm_event_output = lstm_branch(input_shape)
    lstm_agent_inputs, lstm_agent_output = lstm_branch(input_shape)
    lstm_context_inputs, lstm_context_output = lstm_branch(input_shape)
    
    transformer_event_inputs, transformer_event_output = transformer_branch(input_shape)
    transformer_agent_inputs, transformer_agent_output = transformer_branch(input_shape)
    transformer_context_inputs, transformer_context_output = transformer_branch(input_shape)
    
    convnet_event_inputs, convnet_event_output = convnet_branch(input_shape)
    convnet_agent_inputs, convnet_agent_output = convnet_branch(input_shape)
    convnet_context_inputs, convnet_context_output = convnet_branch(input_shape)
    
    # Concatenate outputs from all branches
    concatenated = Concatenate()([
        lstm_event_output, lstm_agent_output, lstm_context_output,
        transformer_event_output, transformer_agent_output, transformer_context_output,
        convnet_event_output, convnet_agent_output, convnet_context_output
    ])
    
    shared_dense = Dense(128, activation='relu')(concatenated)
    
    next_event_head = Dense(num_classes, activation='softmax', name='next_event')(shared_dense)
    agent_head = Dense(num_agents, activation='softmax', name='agent')(shared_dense)
    context_head = Dense(num_contexts, activation='softmax', name='context')(shared_dense)
    anomaly_head = Dense(1, activation='sigmoid', name='anomaly')(shared_dense)
    
    model = Model(inputs=[
        lstm_event_inputs, lstm_agent_inputs, lstm_context_inputs,
        transformer_event_inputs, transformer_agent_inputs, transformer_context_inputs,
        convnet_event_inputs, convnet_agent_inputs, convnet_context_inputs
    ], outputs=[next_event_head, agent_head, context_head, anomaly_head])
    
    return model

# Build the model
model = build_model(sequence_length)

# Define learnable uncertainty parameters
sigma_next_event = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_agent = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_context = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_anomaly = tf.Variable(1.0, dtype=tf.float32, trainable=True)

# Define custom loss functions with uncertainty weighting
def uncertainty_loss(y_true, y_pred, sigma):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)) / (2 * sigma ** 2) + tf.math.log(sigma)

# Compile the model with the custom losses
model.compile(optimizer='adam',
              loss={'next_event': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_next_event),
                    'agent': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_agent),
                    'context': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_context),
                    'anomaly': lambda y_true, y_pred: tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred)) / (2 * sigma_anomaly ** 2) + tf.math.log(sigma_anomaly)},
              metrics={'next_event': 'accuracy', 
                       'agent': 'accuracy',
                       'context': 'accuracy',
                       'anomaly': 'accuracy'})

# Training the model
history = model.fit(
    [train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
     train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
     train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2]],
    {'next_event': train_targets[0], 'agent': train_targets[1], 'context': train_targets[2], 'anomaly': train_targets[3]},
    validation_data=(
        [val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
         val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
         val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2]],
        {'next_event': val_targets[0], 'agent': val_targets[1], 'context': val_targets[2], 'anomaly': val_targets[3]}
    ),
    epochs=50, batch_size=64
)

# Evaluate the model
eval_results = model.evaluate(
    [test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2]],
    {'next_event': test_targets[0], 'agent': test_targets[1], 'context': test_targets[2], 'anomaly': test_targets[3]}
)
print(f"Test Loss and Accuracy: {eval_results}")
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 51s 255ms/step - agent_accuracy: 0.3965 - anomaly_accuracy: 0.5190 - context_accuracy: 0.0747 - loss: 2.6263 - next_event_accuracy: 0.6184 - val_agent_accuracy: 0.4366 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.0986 - val_loss: 2.5313 - val_next_event_accuracy: 0.8028
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - agent_accuracy: 0.4689 - anomaly_accuracy: 0.4932 - context_accuracy: 0.1034 - loss: 2.5260 - next_event_accuracy: 0.7944 - val_agent_accuracy: 0.7535 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.0986 - val_loss: 2.5223 - val_next_event_accuracy: 0.8028
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - agent_accuracy: 0.5196 - anomaly_accuracy: 0.4834 - context_accuracy: 0.1138 - loss: 2.5273 - next_event_accuracy: 0.7827 - val_agent_accuracy: 0.5141 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.0986 - val_loss: 2.4892 - val_next_event_accuracy: 0.8028
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - agent_accuracy: 0.5516 - anomaly_accuracy: 0.5065 - context_accuracy: 0.1174 - loss: 2.4869 - next_event_accuracy: 0.7825 - val_agent_accuracy: 0.8028 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.0986 - val_loss: 2.4358 - val_next_event_accuracy: 0.8028
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - agent_accuracy: 0.7533 - anomaly_accuracy: 0.5402 - context_accuracy: 0.1246 - loss: 2.4164 - next_event_accuracy: 0.7837 - val_agent_accuracy: 0.7183 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1690 - val_loss: 2.3744 - val_next_event_accuracy: 0.8028
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - agent_accuracy: 0.7623 - anomaly_accuracy: 0.5330 - context_accuracy: 0.1932 - loss: 2.3453 - next_event_accuracy: 0.8049 - val_agent_accuracy: 0.8028 - val_anomaly_accuracy: 0.5141 - val_context_accuracy: 0.1831 - val_loss: 2.3412 - val_next_event_accuracy: 0.8028
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - agent_accuracy: 0.8625 - anomaly_accuracy: 0.5551 - context_accuracy: 0.2084 - loss: 2.2970 - next_event_accuracy: 0.7942 - val_agent_accuracy: 0.9930 - val_anomaly_accuracy: 0.5282 - val_context_accuracy: 0.1901 - val_loss: 2.2545 - val_next_event_accuracy: 0.8028
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 0.9983 - anomaly_accuracy: 0.5159 - context_accuracy: 0.2216 - loss: 2.2456 - next_event_accuracy: 0.7896 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.1831 - val_loss: 2.2642 - val_next_event_accuracy: 0.8028
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5633 - context_accuracy: 0.2477 - loss: 2.2439 - next_event_accuracy: 0.7561 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.1831 - val_loss: 2.2392 - val_next_event_accuracy: 0.8028
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5522 - context_accuracy: 0.2235 - loss: 2.2300 - next_event_accuracy: 0.7878 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5352 - val_context_accuracy: 0.2183 - val_loss: 2.2309 - val_next_event_accuracy: 0.8028
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5095 - context_accuracy: 0.2565 - loss: 2.2144 - next_event_accuracy: 0.7868 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.2324 - val_loss: 2.2643 - val_next_event_accuracy: 0.8028
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5199 - context_accuracy: 0.2767 - loss: 2.2129 - next_event_accuracy: 0.7933 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5423 - val_context_accuracy: 0.2113 - val_loss: 2.2362 - val_next_event_accuracy: 0.8028
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5072 - context_accuracy: 0.2754 - loss: 2.2058 - next_event_accuracy: 0.7957 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.2183 - val_loss: 2.2249 - val_next_event_accuracy: 0.8028
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5540 - context_accuracy: 0.2768 - loss: 2.1976 - next_event_accuracy: 0.7783 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.2254 - val_loss: 2.2389 - val_next_event_accuracy: 0.8028
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5430 - context_accuracy: 0.2833 - loss: 2.1965 - next_event_accuracy: 0.7867 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.2324 - val_loss: 2.2363 - val_next_event_accuracy: 0.8028
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5634 - context_accuracy: 0.2852 - loss: 2.1965 - next_event_accuracy: 0.7998 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4296 - val_context_accuracy: 0.2676 - val_loss: 2.2488 - val_next_event_accuracy: 0.8028
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5620 - context_accuracy: 0.3332 - loss: 2.1917 - next_event_accuracy: 0.7889 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4648 - val_context_accuracy: 0.2606 - val_loss: 2.2297 - val_next_event_accuracy: 0.8028
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5841 - context_accuracy: 0.3012 - loss: 2.1896 - next_event_accuracy: 0.7917 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.2676 - val_loss: 2.2224 - val_next_event_accuracy: 0.8028
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6015 - context_accuracy: 0.3085 - loss: 2.1568 - next_event_accuracy: 0.8261 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4930 - val_context_accuracy: 0.3380 - val_loss: 2.1891 - val_next_event_accuracy: 0.8028
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5946 - context_accuracy: 0.3846 - loss: 2.1484 - next_event_accuracy: 0.7893 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4859 - val_context_accuracy: 0.3169 - val_loss: 2.1971 - val_next_event_accuracy: 0.8028
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5982 - context_accuracy: 0.3681 - loss: 2.1547 - next_event_accuracy: 0.7797 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4507 - val_context_accuracy: 0.3380 - val_loss: 2.1916 - val_next_event_accuracy: 0.8028
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5631 - context_accuracy: 0.3816 - loss: 2.1465 - next_event_accuracy: 0.7956 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.3169 - val_loss: 2.1862 - val_next_event_accuracy: 0.8028
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6137 - context_accuracy: 0.3830 - loss: 2.1316 - next_event_accuracy: 0.7850 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4859 - val_context_accuracy: 0.3380 - val_loss: 2.1974 - val_next_event_accuracy: 0.8028
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6201 - context_accuracy: 0.3673 - loss: 2.1336 - next_event_accuracy: 0.7907 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.3239 - val_loss: 2.2201 - val_next_event_accuracy: 0.8028
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5883 - context_accuracy: 0.4174 - loss: 2.1314 - next_event_accuracy: 0.7919 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.3310 - val_loss: 2.1946 - val_next_event_accuracy: 0.8028
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5896 - context_accuracy: 0.3911 - loss: 2.1306 - next_event_accuracy: 0.8085 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.3380 - val_loss: 2.1995 - val_next_event_accuracy: 0.8028
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6079 - context_accuracy: 0.4010 - loss: 2.1278 - next_event_accuracy: 0.7941 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4507 - val_context_accuracy: 0.3239 - val_loss: 2.2133 - val_next_event_accuracy: 0.8028
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5648 - context_accuracy: 0.4102 - loss: 2.1492 - next_event_accuracy: 0.7782 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.3310 - val_loss: 2.2004 - val_next_event_accuracy: 0.8028
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6022 - context_accuracy: 0.3945 - loss: 2.1312 - next_event_accuracy: 0.7861 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.3310 - val_loss: 2.2074 - val_next_event_accuracy: 0.8028
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6092 - context_accuracy: 0.4298 - loss: 2.1124 - next_event_accuracy: 0.7916 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.3239 - val_loss: 2.1976 - val_next_event_accuracy: 0.8028
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6154 - context_accuracy: 0.4133 - loss: 2.1141 - next_event_accuracy: 0.7859 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5352 - val_context_accuracy: 0.3169 - val_loss: 2.1946 - val_next_event_accuracy: 0.8028
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6096 - context_accuracy: 0.4366 - loss: 2.1143 - next_event_accuracy: 0.7731 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.3099 - val_loss: 2.1942 - val_next_event_accuracy: 0.8028
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6449 - context_accuracy: 0.4406 - loss: 2.1081 - next_event_accuracy: 0.7753 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4930 - val_context_accuracy: 0.3310 - val_loss: 2.1928 - val_next_event_accuracy: 0.8028
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6235 - context_accuracy: 0.4336 - loss: 2.1020 - next_event_accuracy: 0.7887 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4859 - val_context_accuracy: 0.3310 - val_loss: 2.1971 - val_next_event_accuracy: 0.8028
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6294 - context_accuracy: 0.4218 - loss: 2.1171 - next_event_accuracy: 0.7878 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.3310 - val_loss: 2.2043 - val_next_event_accuracy: 0.8028
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6215 - context_accuracy: 0.4209 - loss: 2.1060 - next_event_accuracy: 0.7922 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4930 - val_context_accuracy: 0.3310 - val_loss: 2.1974 - val_next_event_accuracy: 0.8028
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6262 - context_accuracy: 0.4763 - loss: 2.0862 - next_event_accuracy: 0.7837 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.3592 - val_loss: 2.2055 - val_next_event_accuracy: 0.8028
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6361 - context_accuracy: 0.4715 - loss: 2.0821 - next_event_accuracy: 0.7854 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5211 - val_context_accuracy: 0.3662 - val_loss: 2.1838 - val_next_event_accuracy: 0.8028
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6528 - context_accuracy: 0.4627 - loss: 2.0851 - next_event_accuracy: 0.7981 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5282 - val_context_accuracy: 0.3662 - val_loss: 2.1939 - val_next_event_accuracy: 0.8028
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6490 - context_accuracy: 0.4737 - loss: 2.0864 - next_event_accuracy: 0.7716 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4507 - val_context_accuracy: 0.3662 - val_loss: 2.2026 - val_next_event_accuracy: 0.8028
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7028 - context_accuracy: 0.4888 - loss: 2.0561 - next_event_accuracy: 0.7893 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4930 - val_context_accuracy: 0.3592 - val_loss: 2.1926 - val_next_event_accuracy: 0.8028
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6589 - context_accuracy: 0.4614 - loss: 2.0659 - next_event_accuracy: 0.8046 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.3451 - val_loss: 2.2123 - val_next_event_accuracy: 0.8028
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6685 - context_accuracy: 0.4951 - loss: 2.0632 - next_event_accuracy: 0.7706 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.3592 - val_loss: 2.2027 - val_next_event_accuracy: 0.8028
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6965 - context_accuracy: 0.4876 - loss: 2.0524 - next_event_accuracy: 0.7903 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4366 - val_context_accuracy: 0.3662 - val_loss: 2.2196 - val_next_event_accuracy: 0.8028
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7066 - context_accuracy: 0.4861 - loss: 2.0507 - next_event_accuracy: 0.7873 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4789 - val_context_accuracy: 0.3521 - val_loss: 2.2084 - val_next_event_accuracy: 0.8028
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6705 - context_accuracy: 0.4735 - loss: 2.0548 - next_event_accuracy: 0.7991 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4859 - val_context_accuracy: 0.3662 - val_loss: 2.2203 - val_next_event_accuracy: 0.8028
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6572 - context_accuracy: 0.4852 - loss: 2.0646 - next_event_accuracy: 0.7885 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5070 - val_context_accuracy: 0.3662 - val_loss: 2.2114 - val_next_event_accuracy: 0.8028
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6942 - context_accuracy: 0.4715 - loss: 2.0514 - next_event_accuracy: 0.7991 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.3521 - val_loss: 2.2199 - val_next_event_accuracy: 0.8028
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7202 - context_accuracy: 0.5045 - loss: 2.0333 - next_event_accuracy: 0.7810 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4577 - val_context_accuracy: 0.3662 - val_loss: 2.2171 - val_next_event_accuracy: 0.8028
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7329 - context_accuracy: 0.5107 - loss: 2.0204 - next_event_accuracy: 0.7840 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4718 - val_context_accuracy: 0.3662 - val_loss: 2.2213 - val_next_event_accuracy: 0.8028
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5202 - context_accuracy: 0.3731 - loss: 2.2138 - next_event_accuracy: 0.7721
# Test Loss and Accuracy: [2.192208766937256, 1.0, 0.559440553188324, 0.37062937021255493, 0.7902097702026367]

# %%
num_samples = 10
sample_sequences = test_sequences[:num_samples]

# Predict the next values
predictions = model.predict(
    [sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2]]
)

# Extract predictions
next_event_predictions = np.argmax(predictions[0], axis=-1)
agent_predictions = np.argmax(predictions[1], axis=-1)
context_predictions = np.argmax(predictions[2], axis=-1)
anomaly_predictions = (predictions[3] > 0.5).astype(int)

# Decode predictions
def decode_predictions(predictions, id_to_label):
    return [id_to_label[idx] for idx in predictions]

decoded_next_event_predictions = decode_predictions(next_event_predictions, event_type_mapping)
decoded_agent_predictions = decode_predictions(agent_predictions, agent_id_mapping)
decoded_context_predictions = decode_predictions(context_predictions, context_mapping)

# Decode input sequences
def decode_sequences(sequences, event_mapping, agent_mapping, context_mapping):
    decoded_sequences = []
    for seq in sequences:
        decoded_seq = []
        for step in seq:
            decoded_step = [
                event_mapping[step[0]],
                agent_mapping[step[1]],
                context_mapping[step[2]]
            ]
            decoded_seq.append(decoded_step)
        decoded_sequences.append(decoded_seq)
    return np.array(decoded_sequences)

decoded_sample_sequences = decode_sequences(sample_sequences, event_type_mapping, agent_id_mapping, context_mapping)

# Print decoded input sequences and predictions
for i in range(num_samples):
    print(f"Input sequence (event_id, agent_id, context):\n{decoded_sample_sequences[i]}")
    print(f"Predicted next event_id: {decoded_next_event_predictions[i]}")
    print(f"Predicted next agent_id: {decoded_agent_predictions[i]}")
    print(f"Predicted next context: {decoded_context_predictions[i]}")
    print(f"Predicted anomaly: {anomaly_predictions[i]}")
    print("-" * 30)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step
# Input sequence (event_id, agent_id, context):
# [['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,0']
#  ['MOVE' 'O' '0,2']
#  ['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']]
# Predicted next event_id: GAME_END
# Predicted next agent_id: system
# Predicted next context: O
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '1,0']
#  ['MOVE' 'O' '0,2']
#  ['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']]
# Predicted next event_id: GAME_START
# Predicted next agent_id: system
# Predicted next context: New Game
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '0,2']
#  ['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 1,2
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '2,1']
#  ['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: O
# Predicted next context: 2,2
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '2,2']
#  ['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 0,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '1,2']
#  ['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: O
# Predicted next context: 1,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '1,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 0,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: O
# Predicted next context: 0,2
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'O' '2,0']
#  ['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['MOVE' 'X' '0,2']]
# Predicted next event_id: MOVE
# Predicted next agent_id: X
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_END' 'system' 'O']
#  ['GAME_START' 'system' 'New Game']
#  ['MOVE' 'X' '1,1']
#  ['MOVE' 'O' '1,0']
#  ['MOVE' 'X' '0,1']
#  ['MOVE' 'O' '2,1']
#  ['MOVE' 'X' '0,0']
#  ['MOVE' 'O' '2,0']
#  ['MOVE' 'X' '0,2']
#  ['GAME_END' 'system' 'X']]
# Predicted next event_id: GAME_END
# Predicted next agent_id: system
# Predicted next context: X
# Predicted anomaly: [1]
# ------------------------------
