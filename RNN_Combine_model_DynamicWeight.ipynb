# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Conv1D, GlobalMaxPooling1D, MultiHeadAttention, LayerNormalization
from tensorflow.keras.models import Model

# Data Preprocessing
def preprocess_data(df):
    event_type_mapping = df['event_type'].astype('category').cat.categories
    agent_id_mapping = df['agent_id'].astype('category').cat.categories
    context_mapping = df['context'].astype('category').cat.categories

    df['event_type'] = df['event_type'].astype('category').cat.codes
    df['agent_id'] = df['agent_id'].astype('category').cat.codes
    df['context'] = df['context'].astype('category').cat.codes

    return df, event_type_mapping, agent_id_mapping, context_mapping

# Load your dataset
df = pd.read_csv('1k_single_agent_minmax.csv')
df, event_type_mapping, agent_id_mapping, context_mapping = preprocess_data(df)

# Define constants
num_classes = df['event_type'].nunique()
num_agents = df['agent_id'].nunique()
num_contexts = df['context'].nunique()
sequence_length = 10  # Adjust based on your data
num_features = df.shape[1]  # Number of features

# Create sequences for training
def create_sequences(df, sequence_length):
    sequences = []
    for i in range(len(df) - sequence_length):
        seq = df.iloc[i:i+sequence_length].values
        sequences.append(seq)
    return np.array(sequences)

sequences = create_sequences(df, sequence_length)

# Splitting the data
train_size = int(0.7 * len(sequences))
val_size = int(0.15 * len(sequences))
train_sequences = sequences[:train_size]
val_sequences = sequences[train_size:train_size+val_size]
test_sequences = sequences[train_size+val_size:]

# Extract targets
def extract_targets(sequences):
    next_event = to_categorical(sequences[:, -1, 0], num_classes=num_classes)
    agent = to_categorical(sequences[:, -1, 1], num_classes=num_agents)
    context = to_categorical(sequences[:, -1, 2], num_classes=num_contexts)
    anomaly = np.random.randint(0, 2, size=(sequences.shape[0], 1))  # Placeholder for anomaly
    return next_event, agent, context, anomaly

train_targets = extract_targets(train_sequences)
val_targets = extract_targets(val_sequences)
test_targets = extract_targets(test_sequences)

# Define the model branches
def lstm_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = LSTM(128, return_sequences=False)(x)
    return inputs, x

def transformer_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = LayerNormalization()(x + attn_output)
    x = GlobalMaxPooling1D()(x)  # Apply GlobalMaxPooling1D to convert 3D to 2D
    return inputs, x

def convnet_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = Conv1D(128, kernel_size=3, activation='relu')(x)
    x = GlobalMaxPooling1D()(x)
    return inputs, x

# Build the model
def build_model(sequence_length):
    input_shape = (sequence_length,)

    # Define the branches for each input
    lstm_event_inputs, lstm_event_output = lstm_branch(input_shape)
    lstm_agent_inputs, lstm_agent_output = lstm_branch(input_shape)
    lstm_context_inputs, lstm_context_output = lstm_branch(input_shape)
    
    transformer_event_inputs, transformer_event_output = transformer_branch(input_shape)
    transformer_agent_inputs, transformer_agent_output = transformer_branch(input_shape)
    transformer_context_inputs, transformer_context_output = transformer_branch(input_shape)
    
    convnet_event_inputs, convnet_event_output = convnet_branch(input_shape)
    convnet_agent_inputs, convnet_agent_output = convnet_branch(input_shape)
    convnet_context_inputs, convnet_context_output = convnet_branch(input_shape)
    
    # Concatenate outputs from all branches
    concatenated = Concatenate()([
        lstm_event_output, lstm_agent_output, lstm_context_output,
        transformer_event_output, transformer_agent_output, transformer_context_output,
        convnet_event_output, convnet_agent_output, convnet_context_output
    ])
    
    shared_dense = Dense(128, activation='relu')(concatenated)
    
    next_event_head = Dense(num_classes, activation='softmax', name='next_event')(shared_dense)
    agent_head = Dense(num_agents, activation='softmax', name='agent')(shared_dense)
    context_head = Dense(num_contexts, activation='softmax', name='context')(shared_dense)
    anomaly_head = Dense(1, activation='sigmoid', name='anomaly')(shared_dense)
    
    model = Model(inputs=[
        lstm_event_inputs, lstm_agent_inputs, lstm_context_inputs,
        transformer_event_inputs, transformer_agent_inputs, transformer_context_inputs,
        convnet_event_inputs, convnet_agent_inputs, convnet_context_inputs
    ], outputs=[next_event_head, agent_head, context_head, anomaly_head])
    
    return model

# Build the model
model = build_model(sequence_length)

# Define learnable uncertainty parameters
sigma_next_event = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_agent = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_context = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_anomaly = tf.Variable(1.0, dtype=tf.float32, trainable=True)

# Define custom loss functions with uncertainty weighting
def uncertainty_loss(y_true, y_pred, sigma):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)) / (2 * sigma ** 2) + tf.math.log(sigma)

# Compile the model with the custom losses
model.compile(optimizer='adam',
              loss={'next_event': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_next_event),
                    'agent': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_agent),
                    'context': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_context),
                    'anomaly': lambda y_true, y_pred: tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred)) / (2 * sigma_anomaly ** 2) + tf.math.log(sigma_anomaly)},
              metrics={'next_event': 'accuracy', 
                       'agent': 'accuracy',
                       'context': 'accuracy',
                       'anomaly': 'accuracy'})

# Training the model
history = model.fit(
    [train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
     train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
     train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2]],
    {'next_event': train_targets[0], 'agent': train_targets[1], 'context': train_targets[2], 'anomaly': train_targets[3]},
    validation_data=(
        [val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
         val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
         val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2]],
        {'next_event': val_targets[0], 'agent': val_targets[1], 'context': val_targets[2], 'anomaly': val_targets[3]}
    ),
    epochs=50, batch_size=64
)

history_df = pd.DataFrame(history.history)
history_df.to_csv('training_results/RNN_Combine_model_DynamicWeight.csv', index=False)

# Evaluate the model
eval_results = model.evaluate(
    [test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2]],
    {'next_event': test_targets[0], 'agent': test_targets[1], 'context': test_targets[2], 'anomaly': test_targets[3]}
)
print(f"Test Loss and Accuracy: {eval_results}")
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 25s 261ms/step - agent_accuracy: 0.3862 - anomaly_accuracy: 0.4955 - context_accuracy: 0.0975 - loss: 2.6269 - next_event_accuracy: 0.7989 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.0878 - val_loss: 2.5701 - val_next_event_accuracy: 0.7973
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - agent_accuracy: 0.3854 - anomaly_accuracy: 0.4965 - context_accuracy: 0.0883 - loss: 2.5619 - next_event_accuracy: 0.8104 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.0946 - val_loss: 2.5637 - val_next_event_accuracy: 0.7973
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 0.3956 - anomaly_accuracy: 0.5177 - context_accuracy: 0.0960 - loss: 2.5663 - next_event_accuracy: 0.7953 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5488 - val_next_event_accuracy: 0.7973
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 0.6193 - anomaly_accuracy: 0.5504 - context_accuracy: 0.1064 - loss: 2.5350 - next_event_accuracy: 0.7980 - val_agent_accuracy: 0.7973 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.0946 - val_loss: 2.4770 - val_next_event_accuracy: 0.7973
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 0.7814 - anomaly_accuracy: 0.5298 - context_accuracy: 0.0976 - loss: 2.4531 - next_event_accuracy: 0.7814 - val_agent_accuracy: 0.7973 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.0946 - val_loss: 2.4040 - val_next_event_accuracy: 0.7973
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 0.8505 - anomaly_accuracy: 0.5117 - context_accuracy: 0.0917 - loss: 2.3870 - next_event_accuracy: 0.7986 - val_agent_accuracy: 0.9865 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.1351 - val_loss: 2.3581 - val_next_event_accuracy: 0.7973
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 0.9769 - anomaly_accuracy: 0.4942 - context_accuracy: 0.1471 - loss: 2.3375 - next_event_accuracy: 0.8088 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.1554 - val_loss: 2.3303 - val_next_event_accuracy: 0.7973
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5325 - context_accuracy: 0.1348 - loss: 2.3095 - next_event_accuracy: 0.8166 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4527 - val_context_accuracy: 0.1014 - val_loss: 2.3080 - val_next_event_accuracy: 0.7973
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5134 - context_accuracy: 0.1618 - loss: 2.2894 - next_event_accuracy: 0.7998 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.0946 - val_loss: 2.3169 - val_next_event_accuracy: 0.7973
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5077 - context_accuracy: 0.1402 - loss: 2.2986 - next_event_accuracy: 0.7982 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.1419 - val_loss: 2.2997 - val_next_event_accuracy: 0.7973
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5280 - context_accuracy: 0.1858 - loss: 2.2677 - next_event_accuracy: 0.8259 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.1622 - val_loss: 2.3013 - val_next_event_accuracy: 0.7973
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5165 - context_accuracy: 0.1989 - loss: 2.2847 - next_event_accuracy: 0.7886 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5338 - val_context_accuracy: 0.1419 - val_loss: 2.2980 - val_next_event_accuracy: 0.7973
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5237 - context_accuracy: 0.1921 - loss: 2.2811 - next_event_accuracy: 0.7967 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.1689 - val_loss: 2.3238 - val_next_event_accuracy: 0.7973
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5421 - context_accuracy: 0.2232 - loss: 2.2651 - next_event_accuracy: 0.8169 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5135 - val_context_accuracy: 0.1892 - val_loss: 2.3003 - val_next_event_accuracy: 0.7973
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5560 - context_accuracy: 0.2575 - loss: 2.2580 - next_event_accuracy: 0.7994 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5203 - val_context_accuracy: 0.2365 - val_loss: 2.2776 - val_next_event_accuracy: 0.7973
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5378 - context_accuracy: 0.2621 - loss: 2.2409 - next_event_accuracy: 0.8102 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.2703 - val_loss: 2.2630 - val_next_event_accuracy: 0.7973
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5419 - context_accuracy: 0.3180 - loss: 2.2178 - next_event_accuracy: 0.8000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5068 - val_context_accuracy: 0.2973 - val_loss: 2.2334 - val_next_event_accuracy: 0.7973
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5525 - context_accuracy: 0.3394 - loss: 2.2019 - next_event_accuracy: 0.8115 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.3311 - val_loss: 2.2312 - val_next_event_accuracy: 0.7973
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5653 - context_accuracy: 0.3859 - loss: 2.1832 - next_event_accuracy: 0.8081 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5068 - val_context_accuracy: 0.3108 - val_loss: 2.2298 - val_next_event_accuracy: 0.7973
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5375 - context_accuracy: 0.3437 - loss: 2.1969 - next_event_accuracy: 0.8094 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4595 - val_context_accuracy: 0.3041 - val_loss: 2.2307 - val_next_event_accuracy: 0.7973
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5534 - context_accuracy: 0.3453 - loss: 2.1918 - next_event_accuracy: 0.7970 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.3108 - val_loss: 2.2286 - val_next_event_accuracy: 0.7973
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5388 - context_accuracy: 0.3625 - loss: 2.1906 - next_event_accuracy: 0.7957 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4865 - val_context_accuracy: 0.2973 - val_loss: 2.2300 - val_next_event_accuracy: 0.7973
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5648 - context_accuracy: 0.3630 - loss: 2.1751 - next_event_accuracy: 0.8108 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4865 - val_context_accuracy: 0.2905 - val_loss: 2.2560 - val_next_event_accuracy: 0.7973
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5495 - context_accuracy: 0.3895 - loss: 2.1767 - next_event_accuracy: 0.7976 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.2838 - val_loss: 2.2332 - val_next_event_accuracy: 0.7973
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5785 - context_accuracy: 0.4071 - loss: 2.1600 - next_event_accuracy: 0.8244 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4797 - val_context_accuracy: 0.2838 - val_loss: 2.2344 - val_next_event_accuracy: 0.7973
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5964 - context_accuracy: 0.4042 - loss: 2.1624 - next_event_accuracy: 0.7990 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5068 - val_context_accuracy: 0.2905 - val_loss: 2.2394 - val_next_event_accuracy: 0.7973
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6009 - context_accuracy: 0.3691 - loss: 2.1564 - next_event_accuracy: 0.8190 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.3446 - val_loss: 2.2178 - val_next_event_accuracy: 0.7973
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6175 - context_accuracy: 0.4280 - loss: 2.1481 - next_event_accuracy: 0.8032 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.3378 - val_loss: 2.2141 - val_next_event_accuracy: 0.7973
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6260 - context_accuracy: 0.4227 - loss: 2.1466 - next_event_accuracy: 0.8075 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4527 - val_context_accuracy: 0.3446 - val_loss: 2.2172 - val_next_event_accuracy: 0.7973
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5967 - context_accuracy: 0.4370 - loss: 2.1378 - next_event_accuracy: 0.8046 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.3581 - val_loss: 2.2152 - val_next_event_accuracy: 0.7973
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6117 - context_accuracy: 0.4316 - loss: 2.1397 - next_event_accuracy: 0.7916 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.3581 - val_loss: 2.2174 - val_next_event_accuracy: 0.7973
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.5854 - context_accuracy: 0.4469 - loss: 2.1424 - next_event_accuracy: 0.7964 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4797 - val_context_accuracy: 0.3581 - val_loss: 2.1798 - val_next_event_accuracy: 0.8986
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6283 - context_accuracy: 0.4796 - loss: 2.0781 - next_event_accuracy: 0.9054 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.3446 - val_loss: 2.1654 - val_next_event_accuracy: 0.8986
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6251 - context_accuracy: 0.4489 - loss: 2.0815 - next_event_accuracy: 0.8934 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4527 - val_context_accuracy: 0.3649 - val_loss: 2.1553 - val_next_event_accuracy: 0.9054
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6288 - context_accuracy: 0.4587 - loss: 2.0576 - next_event_accuracy: 0.9318 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4797 - val_context_accuracy: 0.3649 - val_loss: 2.1377 - val_next_event_accuracy: 1.0000
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6242 - context_accuracy: 0.4769 - loss: 2.0221 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.3581 - val_loss: 2.1368 - val_next_event_accuracy: 1.0000
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6461 - context_accuracy: 0.4508 - loss: 2.0253 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.3649 - val_loss: 2.1315 - val_next_event_accuracy: 1.0000
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6268 - context_accuracy: 0.4431 - loss: 2.0278 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.3649 - val_loss: 2.1314 - val_next_event_accuracy: 1.0000
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6717 - context_accuracy: 0.4487 - loss: 2.0183 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.3649 - val_loss: 2.1429 - val_next_event_accuracy: 1.0000
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6498 - context_accuracy: 0.4626 - loss: 2.0078 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.3716 - val_loss: 2.1263 - val_next_event_accuracy: 1.0000
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6844 - context_accuracy: 0.4512 - loss: 2.0136 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4459 - val_context_accuracy: 0.3716 - val_loss: 2.1470 - val_next_event_accuracy: 1.0000
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6536 - context_accuracy: 0.4780 - loss: 1.9962 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4932 - val_context_accuracy: 0.3649 - val_loss: 2.1381 - val_next_event_accuracy: 1.0000
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6934 - context_accuracy: 0.4972 - loss: 1.9810 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.5000 - val_context_accuracy: 0.3649 - val_loss: 2.1460 - val_next_event_accuracy: 1.0000
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6747 - context_accuracy: 0.4637 - loss: 1.9961 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4324 - val_context_accuracy: 0.3649 - val_loss: 2.1479 - val_next_event_accuracy: 1.0000
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.6755 - context_accuracy: 0.4793 - loss: 1.9893 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.3716 - val_loss: 2.1409 - val_next_event_accuracy: 1.0000
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7235 - context_accuracy: 0.4956 - loss: 1.9672 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4595 - val_context_accuracy: 0.3784 - val_loss: 2.1551 - val_next_event_accuracy: 1.0000
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7155 - context_accuracy: 0.4958 - loss: 1.9682 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4459 - val_context_accuracy: 0.3649 - val_loss: 2.1529 - val_next_event_accuracy: 1.0000
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7091 - context_accuracy: 0.4828 - loss: 1.9720 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4392 - val_context_accuracy: 0.3716 - val_loss: 2.1571 - val_next_event_accuracy: 1.0000
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7131 - context_accuracy: 0.4886 - loss: 1.9711 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.3784 - val_loss: 2.1602 - val_next_event_accuracy: 1.0000
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.7290 - context_accuracy: 0.4947 - loss: 1.9579 - next_event_accuracy: 1.0000 - val_agent_accuracy: 1.0000 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.3716 - val_loss: 2.1628 - val_next_event_accuracy: 1.0000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - agent_accuracy: 1.0000 - anomaly_accuracy: 0.4875 - context_accuracy: 0.3702 - loss: 2.1313 - next_event_accuracy: 1.0000
# Test Loss and Accuracy: [2.152204990386963, 1.0, 0.4899328947067261, 0.34899330139160156, 1.0]

# %%
num_samples = 10
sample_sequences = test_sequences[:num_samples]

# Predict the next values
predictions = model.predict(
    [sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2]]
)

# Extract predictions
next_event_predictions = np.argmax(predictions[0], axis=-1)
agent_predictions = np.argmax(predictions[1], axis=-1)
context_predictions = np.argmax(predictions[2], axis=-1)
anomaly_predictions = (predictions[3] > 0.5).astype(int)

# Decode predictions
def decode_predictions(predictions, id_to_label):
    return [id_to_label[idx] for idx in predictions]

decoded_next_event_predictions = decode_predictions(next_event_predictions, event_type_mapping)
decoded_agent_predictions = decode_predictions(agent_predictions, agent_id_mapping)
decoded_context_predictions = decode_predictions(context_predictions, context_mapping)

# Decode input sequences
def decode_sequences(sequences, event_mapping, agent_mapping, context_mapping):
    decoded_sequences = []
    for seq in sequences:
        decoded_seq = []
        for step in seq:
            decoded_step = [
                event_mapping[step[0]],
                agent_mapping[step[1]],
                context_mapping[step[2]]
            ]
            decoded_seq.append(decoded_step)
        decoded_sequences.append(decoded_seq)
    return np.array(decoded_sequences)

decoded_sample_sequences = decode_sequences(sample_sequences, event_type_mapping, agent_id_mapping, context_mapping)

# Print decoded input sequences and predictions
for i in range(num_samples):
    print(f"Input sequence (event_id, agent_id, context):\n{decoded_sample_sequences[i]}")
    print(f"Predicted next event_id: {decoded_next_event_predictions[i]}")
    print(f"Predicted next agent_id: {decoded_agent_predictions[i]}")
    print(f"Predicted next context: {decoded_context_predictions[i]}")
    print(f"Predicted anomaly: {anomaly_predictions[i]}")
    print("-" * 30)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '2,2']
#  ['MOVE' 'opponent_move' '1,2']
#  ['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 1,1
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,2']
#  ['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 0,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']]
# Predicted next event_id: MOVE
# Predicted next agent_id: system
# Predicted next context: 2,1
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']]
# Predicted next event_id: MOVE
# Predicted next agent_id: system
# Predicted next context: New Game - Playing as O
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 1,1
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 1,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 0,1
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']
#  ['MOVE' 'opponent_move' '1,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 2,1
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '1,2']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,2
# Predicted anomaly: [0]
# ------------------------------
