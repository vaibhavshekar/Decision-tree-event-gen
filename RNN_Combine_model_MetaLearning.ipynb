# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Concatenate, Conv1D, GlobalMaxPooling1D, MultiHeadAttention, LayerNormalization, Lambda
from tensorflow.keras.models import Model

# Data Preprocessing
def preprocess_data(df):
    event_type_mapping = df['event_type'].astype('category').cat.categories
    agent_id_mapping = df['agent_id'].astype('category').cat.categories
    context_mapping = df['context'].astype('category').cat.categories

    df['event_type'] = df['event_type'].astype('category').cat.codes
    df['agent_id'] = df['agent_id'].astype('category').cat.codes
    df['context'] = df['context'].astype('category').cat.codes

    return df, event_type_mapping, agent_id_mapping, context_mapping

# Load your dataset
df = pd.read_csv('1k_single_agent_minmax.csv')
df, event_type_mapping, agent_id_mapping, context_mapping = preprocess_data(df)

# Define constants
num_classes = df['event_type'].nunique()
num_agents = df['agent_id'].nunique()
num_contexts = df['context'].nunique()
sequence_length = 10  # Adjust based on your data
num_features = df.shape[1]  # Number of features

# Create sequences for training
def create_sequences(df, sequence_length):
    sequences = []
    for i in range(len(df) - sequence_length):
        seq = df.iloc[i:i+sequence_length].values
        sequences.append(seq)
    return np.array(sequences)

sequences = create_sequences(df, sequence_length)

# Splitting the data
train_size = int(0.7 * len(sequences))
val_size = int(0.15 * len(sequences))
train_sequences = sequences[:train_size]
val_sequences = sequences[train_size:train_size+val_size]
test_sequences = sequences[train_size+val_size:]

# Extract targets
def extract_targets(sequences):
    next_event = to_categorical(sequences[:, -1, 0], num_classes=num_classes)
    agent = to_categorical(sequences[:, -1, 1], num_classes=num_agents)
    context = to_categorical(sequences[:, -1, 2], num_classes=num_contexts)
    anomaly = np.random.randint(0, 2, size=(sequences.shape[0], 1))  # Placeholder for anomaly
    return next_event, agent, context, anomaly

train_targets = extract_targets(train_sequences)
val_targets = extract_targets(val_sequences)
test_targets = extract_targets(test_sequences)

# Define the model branches
def lstm_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = LSTM(128, return_sequences=False)(x)
    return inputs, x

def transformer_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    attn_output = MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = LayerNormalization()(x + attn_output)
    x = GlobalMaxPooling1D()(x)  # Apply GlobalMaxPooling1D to convert 3D to 2D
    return inputs, x

def convnet_branch(input_shape):
    inputs = Input(shape=input_shape)
    x = Embedding(input_dim=num_classes, output_dim=64)(inputs)
    x = Conv1D(128, kernel_size=3, activation='relu')(x)
    x = GlobalMaxPooling1D()(x)
    return inputs, x

# Build the model
def build_model(sequence_length):
    input_shape = (sequence_length,)

    # Define the branches for each input
    lstm_event_inputs, lstm_event_output = lstm_branch(input_shape)
    lstm_agent_inputs, lstm_agent_output = lstm_branch(input_shape)
    lstm_context_inputs, lstm_context_output = lstm_branch(input_shape)
    
    transformer_event_inputs, transformer_event_output = transformer_branch(input_shape)
    transformer_agent_inputs, transformer_agent_output = transformer_branch(input_shape)
    transformer_context_inputs, transformer_context_output = transformer_branch(input_shape)
    
    convnet_event_inputs, convnet_event_output = convnet_branch(input_shape)
    convnet_agent_inputs, convnet_agent_output = convnet_branch(input_shape)
    convnet_context_inputs, convnet_context_output = convnet_branch(input_shape)
    
    # Concatenate outputs from all branches
    concatenated = Concatenate()([
        lstm_event_output, lstm_agent_output, lstm_context_output,
        transformer_event_output, transformer_agent_output, transformer_context_output,
        convnet_event_output, convnet_agent_output, convnet_context_output
    ])
    
    shared_dense = Dense(128, activation='relu')(concatenated)
    
    next_event_head = Dense(num_classes, activation='softmax', name='next_event')(shared_dense)
    agent_head = Dense(num_agents, activation='softmax', name='agent')(shared_dense)
    context_head = Dense(num_contexts, activation='softmax', name='context')(shared_dense)
    anomaly_head = Dense(1, activation='sigmoid', name='anomaly')(shared_dense)
    
    model = Model(inputs=[
        lstm_event_inputs, lstm_agent_inputs, lstm_context_inputs,
        transformer_event_inputs, transformer_agent_inputs, transformer_context_inputs,
        convnet_event_inputs, convnet_agent_inputs, convnet_context_inputs
    ], outputs=[next_event_head, agent_head, context_head, anomaly_head])
    
    return model

# Build the model
model = build_model(sequence_length)

# Define learnable uncertainty parameters
sigma_next_event = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_agent = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_context = tf.Variable(1.0, dtype=tf.float32, trainable=True)
sigma_anomaly = tf.Variable(1.0, dtype=tf.float32, trainable=True)

# Define custom loss functions with uncertainty weighting
def uncertainty_loss(y_true, y_pred, sigma):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)) / (2 * sigma ** 2) + tf.math.log(sigma)

# Define meta-learner model for learning rate adjustment
meta_input = Input(shape=(1,))
meta_output = Dense(1, activation='linear')(meta_input)
meta_model = Model(meta_input, meta_output)
meta_model.compile(optimizer='adam', loss='mse')

# Initial learning rate
initial_lr = 1e-3
model_optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)

# Compile the base model with the custom losses
model.compile(optimizer=model_optimizer,
              loss={'next_event': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_next_event),
                    'agent': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_agent),
                    'context': lambda y_true, y_pred: uncertainty_loss(y_true, y_pred, sigma_context),
                    'anomaly': lambda y_true, y_pred: tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred)) / (2 * sigma_anomaly ** 2) + tf.math.log(sigma_anomaly)},
              metrics={'next_event': 'accuracy', 
                       'agent': 'accuracy',
                       'context': 'accuracy',
                       'anomaly': 'accuracy'})

# Training the model with meta-learning
# Training the model with meta-learning
for epoch in range(50):
    print(f"Epoch {epoch+1}/50")
    
    # Train the base model
    history = model.fit(
        [train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
         train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2],
         train_sequences[:,:,0], train_sequences[:,:,1], train_sequences[:,:,2]],
        {'next_event': train_targets[0], 'agent': train_targets[1], 'context': train_targets[2], 'anomaly': train_targets[3]},
        validation_data=(
            [val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
             val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2],
             val_sequences[:,:,0], val_sequences[:,:,1], val_sequences[:,:,2]],
            {'next_event': val_targets[0], 'agent': val_targets[1], 'context': val_targets[2], 'anomaly': val_targets[3]}
        ),
        epochs=1, batch_size=64
    )
    
    # Get the validation loss
    val_loss = history.history['val_loss'][-1]
    
    # Meta-learning step: Update learning rate
    current_lr = model.optimizer.learning_rate.numpy()
    new_lr = meta_model.predict(np.array([[val_loss]]))
    new_lr = np.clip(new_lr, 1e-6, 1e-2)  # Clipping to prevent too large or small learning rates
    model.optimizer.learning_rate.assign(new_lr[0, 0])
    print(f"Updated learning rate: {new_lr[0, 0]}")

history_df = pd.DataFrame(history.history)
history_df.to_csv('training_results/RNN_Combine_model_MetaLearning.csv', index=False)
# Evaluate the model
eval_results = model.evaluate(
    [test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2],
     test_sequences[:,:,0], test_sequences[:,:,1], test_sequences[:,:,2]],
    {'next_event': test_targets[0], 'agent': test_targets[1], 'context': test_targets[2], 'anomaly': test_targets[3]}
)
print(f"Test Loss and Accuracy: {eval_results}")
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 45s 895ms/step - agent_accuracy: 0.3937 - anomaly_accuracy: 0.5263 - context_accuracy: 0.1128 - loss: 2.6429 - next_event_accuracy: 0.6320 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5768 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - agent_accuracy: 0.3733 - anomaly_accuracy: 0.5049 - context_accuracy: 0.0961 - loss: 2.5769 - next_event_accuracy: 0.7929 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5767 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - agent_accuracy: 0.3831 - anomaly_accuracy: 0.4915 - context_accuracy: 0.0823 - loss: 2.5819 - next_event_accuracy: 0.7887 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5764 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - agent_accuracy: 0.4006 - anomaly_accuracy: 0.4847 - context_accuracy: 0.0708 - loss: 2.5713 - next_event_accuracy: 0.8073 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5761 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - agent_accuracy: 0.3907 - anomaly_accuracy: 0.4897 - context_accuracy: 0.0849 - loss: 2.5870 - next_event_accuracy: 0.7796 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5758 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - agent_accuracy: 0.3949 - anomaly_accuracy: 0.4854 - context_accuracy: 0.0847 - loss: 2.5748 - next_event_accuracy: 0.7970 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5755 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - agent_accuracy: 0.3815 - anomaly_accuracy: 0.4872 - context_accuracy: 0.0819 - loss: 2.5790 - next_event_accuracy: 0.7922 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5752 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - agent_accuracy: 0.3770 - anomaly_accuracy: 0.4778 - context_accuracy: 0.0930 - loss: 2.5877 - next_event_accuracy: 0.7799 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5749 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - agent_accuracy: 0.3935 - anomaly_accuracy: 0.5266 - context_accuracy: 0.1039 - loss: 2.5605 - next_event_accuracy: 0.8076 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5747 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - agent_accuracy: 0.4221 - anomaly_accuracy: 0.4984 - context_accuracy: 0.0966 - loss: 2.5552 - next_event_accuracy: 0.8166 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5744 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - agent_accuracy: 0.4101 - anomaly_accuracy: 0.5191 - context_accuracy: 0.0785 - loss: 2.5521 - next_event_accuracy: 0.8240 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5741 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - agent_accuracy: 0.3920 - anomaly_accuracy: 0.4847 - context_accuracy: 0.0814 - loss: 2.5734 - next_event_accuracy: 0.7975 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5738 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - agent_accuracy: 0.4028 - anomaly_accuracy: 0.5034 - context_accuracy: 0.0811 - loss: 2.5834 - next_event_accuracy: 0.7794 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5736 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - agent_accuracy: 0.4023 - anomaly_accuracy: 0.5086 - context_accuracy: 0.0765 - loss: 2.5715 - next_event_accuracy: 0.7953 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5734 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - agent_accuracy: 0.3976 - anomaly_accuracy: 0.4977 - context_accuracy: 0.0839 - loss: 2.5797 - next_event_accuracy: 0.7866 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5732 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - agent_accuracy: 0.4015 - anomaly_accuracy: 0.4927 - context_accuracy: 0.0761 - loss: 2.5749 - next_event_accuracy: 0.7967 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.0946 - val_loss: 2.5729 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - agent_accuracy: 0.3937 - anomaly_accuracy: 0.5086 - context_accuracy: 0.0810 - loss: 2.5841 - next_event_accuracy: 0.7763 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.0946 - val_loss: 2.5727 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - agent_accuracy: 0.3889 - anomaly_accuracy: 0.5223 - context_accuracy: 0.0890 - loss: 2.5798 - next_event_accuracy: 0.7825 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4527 - val_context_accuracy: 0.0946 - val_loss: 2.5726 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - agent_accuracy: 0.4047 - anomaly_accuracy: 0.5234 - context_accuracy: 0.0843 - loss: 2.5719 - next_event_accuracy: 0.7944 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4459 - val_context_accuracy: 0.0946 - val_loss: 2.5724 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - agent_accuracy: 0.3891 - anomaly_accuracy: 0.4983 - context_accuracy: 0.0942 - loss: 2.5585 - next_event_accuracy: 0.8093 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4730 - val_context_accuracy: 0.0946 - val_loss: 2.5722 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - agent_accuracy: 0.3846 - anomaly_accuracy: 0.5084 - context_accuracy: 0.0834 - loss: 2.5692 - next_event_accuracy: 0.8020 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4595 - val_context_accuracy: 0.0946 - val_loss: 2.5721 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - agent_accuracy: 0.3931 - anomaly_accuracy: 0.4868 - context_accuracy: 0.0848 - loss: 2.5631 - next_event_accuracy: 0.8101 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4595 - val_context_accuracy: 0.0946 - val_loss: 2.5719 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - agent_accuracy: 0.3871 - anomaly_accuracy: 0.5358 - context_accuracy: 0.1004 - loss: 2.5717 - next_event_accuracy: 0.7920 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4662 - val_context_accuracy: 0.0946 - val_loss: 2.5717 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - agent_accuracy: 0.4036 - anomaly_accuracy: 0.5224 - context_accuracy: 0.0869 - loss: 2.5722 - next_event_accuracy: 0.7912 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.4797 - val_context_accuracy: 0.0946 - val_loss: 2.5716 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - agent_accuracy: 0.3939 - anomaly_accuracy: 0.5428 - context_accuracy: 0.0786 - loss: 2.5523 - next_event_accuracy: 0.8196 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5068 - val_context_accuracy: 0.0946 - val_loss: 2.5715 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - agent_accuracy: 0.4051 - anomaly_accuracy: 0.5232 - context_accuracy: 0.0870 - loss: 2.5550 - next_event_accuracy: 0.8149 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5338 - val_context_accuracy: 0.0946 - val_loss: 2.5713 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - agent_accuracy: 0.4040 - anomaly_accuracy: 0.5080 - context_accuracy: 0.0935 - loss: 2.5618 - next_event_accuracy: 0.8063 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5203 - val_context_accuracy: 0.0946 - val_loss: 2.5712 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - agent_accuracy: 0.4017 - anomaly_accuracy: 0.5290 - context_accuracy: 0.0710 - loss: 2.5779 - next_event_accuracy: 0.7891 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5203 - val_context_accuracy: 0.0946 - val_loss: 2.5711 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - agent_accuracy: 0.4047 - anomaly_accuracy: 0.5144 - context_accuracy: 0.0863 - loss: 2.5607 - next_event_accuracy: 0.8046 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5710 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - agent_accuracy: 0.3923 - anomaly_accuracy: 0.5329 - context_accuracy: 0.0856 - loss: 2.5620 - next_event_accuracy: 0.8074 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5708 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - agent_accuracy: 0.4229 - anomaly_accuracy: 0.5172 - context_accuracy: 0.0919 - loss: 2.5592 - next_event_accuracy: 0.8070 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5708 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - agent_accuracy: 0.4177 - anomaly_accuracy: 0.5102 - context_accuracy: 0.0946 - loss: 2.5545 - next_event_accuracy: 0.8152 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5405 - val_context_accuracy: 0.0946 - val_loss: 2.5707 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - agent_accuracy: 0.4160 - anomaly_accuracy: 0.5186 - context_accuracy: 0.0978 - loss: 2.5590 - next_event_accuracy: 0.8060 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5473 - val_context_accuracy: 0.0946 - val_loss: 2.5706 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - agent_accuracy: 0.4125 - anomaly_accuracy: 0.5077 - context_accuracy: 0.0878 - loss: 2.5612 - next_event_accuracy: 0.8051 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5473 - val_context_accuracy: 0.0946 - val_loss: 2.5705 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - agent_accuracy: 0.3914 - anomaly_accuracy: 0.5185 - context_accuracy: 0.0826 - loss: 2.5734 - next_event_accuracy: 0.7918 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5473 - val_context_accuracy: 0.0946 - val_loss: 2.5704 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - agent_accuracy: 0.3841 - anomaly_accuracy: 0.5271 - context_accuracy: 0.0868 - loss: 2.5588 - next_event_accuracy: 0.8126 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5473 - val_context_accuracy: 0.0946 - val_loss: 2.5703 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - agent_accuracy: 0.4107 - anomaly_accuracy: 0.4902 - context_accuracy: 0.0804 - loss: 2.5623 - next_event_accuracy: 0.8080 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5702 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - agent_accuracy: 0.4254 - anomaly_accuracy: 0.5167 - context_accuracy: 0.0792 - loss: 2.5516 - next_event_accuracy: 0.8191 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5702 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - agent_accuracy: 0.3948 - anomaly_accuracy: 0.5104 - context_accuracy: 0.0877 - loss: 2.5678 - next_event_accuracy: 0.7991 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5702 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - agent_accuracy: 0.3941 - anomaly_accuracy: 0.5058 - context_accuracy: 0.0818 - loss: 2.5570 - next_event_accuracy: 0.8143 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5338 - val_context_accuracy: 0.0946 - val_loss: 2.5701 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - agent_accuracy: 0.3911 - anomaly_accuracy: 0.5215 - context_accuracy: 0.0724 - loss: 2.5777 - next_event_accuracy: 0.7882 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5700 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - agent_accuracy: 0.4135 - anomaly_accuracy: 0.5181 - context_accuracy: 0.0773 - loss: 2.5748 - next_event_accuracy: 0.7895 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5338 - val_context_accuracy: 0.0946 - val_loss: 2.5700 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - agent_accuracy: 0.4028 - anomaly_accuracy: 0.5042 - context_accuracy: 0.0880 - loss: 2.5544 - next_event_accuracy: 0.8172 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5699 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - agent_accuracy: 0.4079 - anomaly_accuracy: 0.5322 - context_accuracy: 0.0915 - loss: 2.5577 - next_event_accuracy: 0.8096 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5270 - val_context_accuracy: 0.0946 - val_loss: 2.5699 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - agent_accuracy: 0.4041 - anomaly_accuracy: 0.4953 - context_accuracy: 0.0742 - loss: 2.5658 - next_event_accuracy: 0.8036 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5338 - val_context_accuracy: 0.0946 - val_loss: 2.5698 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - agent_accuracy: 0.3979 - anomaly_accuracy: 0.5117 - context_accuracy: 0.0906 - loss: 2.5718 - next_event_accuracy: 0.7921 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5405 - val_context_accuracy: 0.0946 - val_loss: 2.5698 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - agent_accuracy: 0.4208 - anomaly_accuracy: 0.4864 - context_accuracy: 0.0875 - loss: 2.5659 - next_event_accuracy: 0.8002 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5473 - val_context_accuracy: 0.0946 - val_loss: 2.5697 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - agent_accuracy: 0.3992 - anomaly_accuracy: 0.5180 - context_accuracy: 0.0919 - loss: 2.5571 - next_event_accuracy: 0.8112 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5405 - val_context_accuracy: 0.0946 - val_loss: 2.5697 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - agent_accuracy: 0.4072 - anomaly_accuracy: 0.5263 - context_accuracy: 0.1076 - loss: 2.5602 - next_event_accuracy: 0.8040 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5541 - val_context_accuracy: 0.0946 - val_loss: 2.5696 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Updated learning rate: 9.999999974752427e-07
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - agent_accuracy: 0.4079 - anomaly_accuracy: 0.5080 - context_accuracy: 0.0854 - loss: 2.5700 - next_event_accuracy: 0.7964 - val_agent_accuracy: 0.3986 - val_anomaly_accuracy: 0.5405 - val_context_accuracy: 0.0946 - val_loss: 2.5696 - val_next_event_accuracy: 0.7973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Updated learning rate: 9.999999974752427e-07
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - agent_accuracy: 0.4020 - anomaly_accuracy: 0.5689 - context_accuracy: 0.0737 - loss: 2.5668 - next_event_accuracy: 0.8018
# Test Loss and Accuracy: [2.5695230960845947, 0.4026845693588257, 0.5503355860710144, 0.07382550090551376, 0.7986577153205872]

# %%
num_samples = 10
sample_sequences = test_sequences[:num_samples]

# Predict the next values
predictions = model.predict(
    [sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2],
     sample_sequences[:,:,0], sample_sequences[:,:,1], sample_sequences[:,:,2]]
)

# Extract predictions
next_event_predictions = np.argmax(predictions[0], axis=-1)
agent_predictions = np.argmax(predictions[1], axis=-1)
context_predictions = np.argmax(predictions[2], axis=-1)
anomaly_predictions = (predictions[3] > 0.5).astype(int)

# Decode predictions
def decode_predictions(predictions, id_to_label):
    return [id_to_label[idx] for idx in predictions]

decoded_next_event_predictions = decode_predictions(next_event_predictions, event_type_mapping)
decoded_agent_predictions = decode_predictions(agent_predictions, agent_id_mapping)
decoded_context_predictions = decode_predictions(context_predictions, context_mapping)

# Decode input sequences
def decode_sequences(sequences, event_mapping, agent_mapping, context_mapping):
    decoded_sequences = []
    for seq in sequences:
        decoded_seq = []
        for step in seq:
            decoded_step = [
                event_mapping[step[0]],
                agent_mapping[step[1]],
                context_mapping[step[2]]
            ]
            decoded_seq.append(decoded_step)
        decoded_sequences.append(decoded_seq)
    return np.array(decoded_sequences)

decoded_sample_sequences = decode_sequences(sample_sequences, event_type_mapping, agent_id_mapping, context_mapping)

# Print decoded input sequences and predictions
for i in range(num_samples):
    print(f"Input sequence (event_id, agent_id, context):\n{decoded_sample_sequences[i]}")
    print(f"Predicted next event_id: {decoded_next_event_predictions[i]}")
    print(f"Predicted next agent_id: {decoded_agent_predictions[i]}")
    print(f"Predicted next context: {decoded_context_predictions[i]}")
    print(f"Predicted anomaly: {anomaly_predictions[i]}")
    print("-" * 30)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '2,2']
#  ['MOVE' 'opponent_move' '1,2']
#  ['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: opponent_move
# Predicted next context: 2,0
# Predicted anomaly: [0]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,2']
#  ['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '2,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,0']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['GAME_START' 'system' 'New Game - Playing as X']
#  ['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '0,2']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'my_move' '0,0']
#  ['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']
#  ['MOVE' 'opponent_move' '1,0']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
# Input sequence (event_id, agent_id, context):
# [['MOVE' 'opponent_move' '2,0']
#  ['MOVE' 'my_move' '0,1']
#  ['GAME_END' 'system' 'X']
#  ['GAME_START' 'system' 'New Game - Playing as O']
#  ['MOVE' 'opponent_move' '2,1']
#  ['MOVE' 'my_move' '2,0']
#  ['MOVE' 'opponent_move' '1,1']
#  ['MOVE' 'my_move' '0,1']
#  ['MOVE' 'opponent_move' '1,0']
#  ['MOVE' 'my_move' '1,2']]
# Predicted next event_id: MOVE
# Predicted next agent_id: my_move
# Predicted next context: 2,0
# Predicted anomaly: [1]
# ------------------------------
